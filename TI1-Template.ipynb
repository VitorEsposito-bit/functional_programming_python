# %% [markdown]
# # [Prof. Dalvan Griebler](mailto:dalvan.griebler@pucrs.br)
#
# ## Programação Orientada a Dados (POD) - Turma 10 (POD_98H04-06)
#
# **Atualizado**: 01/06/2024
#
# **Descrição**: Trabalho Individual: Programação Funcional
#
# **Copyright &copy;**: Este documento está sob a licensa da Criative Commons [BY-NC-ND 4.0](https://creativecommons.org/licenses/by-nc-nd/4.0/legalcode)
#
# **Dataset**: [Formula 1 Official Data (1950-2022)](https://www.kaggle.com/datasets/debashish311601/formula-1-official-data-19502022)

# %% [markdown]
# <font color="orange">
# <b>
# Atenção: Explicar como funcionam todas as função criadas através de comentário do Python (`#`). Você também será avaliado por esta explicação.
# </font>

# %% [markdown]
# <font color="blue">
# <b>
# Definição resumida sobre funções do paradigma funcional:<br>
#    &nbsp;&nbsp;&nbsp;&nbsp; <ins>são funções que são puras, que não apresentam efeito colateral, podem ser de alta ordem, podem ser currificadas e não utilizam laços de repetição.</ins>
# </b>
# </font>

# %% [markdown]
# ### Trabalho realizado por:

# %% [markdown]
# ## Parte 1: Dataset Fórmula 1 (1950-2022)

# %% [markdown]
# ### Módulos autorizados

# %%
import csv
from functools import reduce
from itertools import *

# %% [markdown]
# ### Funções auxiliares

# %%
def mostra_dados(titulo, nome_arq, f, *args):
    """
    Função auxiliar para mostrar o resultado da execução de uma função do paradigma funcional.
    A função abre um arquivo CSV e passa para função do paradigma funcional um objeto DictReader e 
    depois mostra o resultado na tela.
    """
    print("|___   ", titulo, "  ___|")
    with open(nome_arq, "r", encoding='utf-8-sig') as arq:
        dados = csv.DictReader(arq, delimiter=',')
        fdados = f(dados, *args)
        try:
            iterator = iter(fdados)
        except TypeError:
            print(fdados)
        else:
            for linha in fdados:
                print(linha)

def retorna_dados(nome_arq):
    """
    Função auxiliar que retorna os dados em formato de um objeto DictReader após a leitura de um arquivo!
    """
    with open(nome_arq, "r", encoding='utf-8-sig') as arq:
        dados = csv.DictReader(arq, delimiter=',')
        for linha in dados:
            for chave, valor in linha.items():
                linha[chave] = valor.strip()  # reassign
            yield linha        
                
def salvar_dados(nome_arq, new_file, f):
    """
    Função auxiliar que chama uma função do paradigma funcional e depois salva o resultado em um arquivo CSV!
    A função abre um arquivo CSV e passa para função do paradigma funcional um objeto DictReader e 
    depois salva a saída em um arquivo CSV
    """
    with open(nome_arq, "r", encoding='utf-8-sig') as arq:
        dados=csv.DictReader(arq, delimiter=',')
        fdados = list(f(dados))
        fieldnames = fdados[0].keys()
        
    with open(new_file, "w", encoding='utf-8-sig') as arq:
        try:
            iterator=iter(fdados)
        except TypeError:
            return False
        else:
            writer = csv.DictWriter(arq, fieldnames=fieldnames)
            writer.writeheader()
            for i in fdados:
                writer.writerow(i)

# %% [markdown]
# **1. Escreva uma ou mais funções do paradigma funcional, cujo o objetivo desta tarefa é ler dados do arquivo "race_summaries.csv" e retorne a quantidade total de vitórias que cada piloto obteve na Fórmula 1. O resultado deve ser apresentado em formato de uma tupla com nome do piloto e quantidade de vitórias.**
#
# - **Para testar, é necessário usar a função auxiliar `mostra_dados` conforme apresentado abaixo.**
# ```python
# mostra_dados("quantidade_de_vitorias_do_piloto", "race_summaries.csv", quantidade_de_vitorias_do_piloto)
# ```
#
# - **Exemplo de saída esperada:**
# ```bash
# |___    quantidade_de_vitorias   ___|
# ('Alain Prost', 51)
# ('Alan Jones', 12)
# ('Alberto Ascari', 13)
# ('Alessandro Nannini', 1)
# ('Ayrton Senna', 41)
# ('Bill Vukovich', 2)
# ('Bob Sweikert', 1)
# ('Bruce McLaren', 4)
# ('Carlos Pace', 1)
# ('Carlos Reutemann', 12)
# ('Carlos Sainz', 1)
# ('Charles Leclerc', 5)
# ('Clay Regazzoni', 5)
# ...
# ```

# %%
def retorna_nome(lista_tuplas): #Função que retorna o primeiro elemento referente a primeira tupla da lista recebida como argumento.
    return lista_tuplas[0][0]

def conta_vitorias(lista): #Função que itera sobre a lista recebida como argumento, de forma recursiva, e retorna o tamanho da mesma.
    if lista == []:
        return 0
    else:
        return 1 + conta_vitorias(lista[1:])

def organiza_resultado(lista_tuplas,dicionarios): #Função que chama as outras funções, e organiza os dados em uma lista de tuplas.
    if lista_tuplas == []:
        return []
    else:
        return [(retorna_nome(lista_tuplas),conta_vitorias(list(filter(lambda x: x["Winner"] == retorna_nome(lista_tuplas),dicionarios))))] + organiza_resultado(lista_tuplas[1:],dicionarios)
    

def quantidade_de_vitorias_piloto(iterador): #Função que recebe um iterador, o ordena e transforma os dados, assim os passa como argumento para a função organiza_resultado.
    dicionarios_ordenados = list(sorted(iterador,key=lambda dicionario: dicionario["Winner"]))
    tuplas_pilotos = sorted(set(map(lambda x: (x["Winner"],),dicionarios_ordenados)))
    return organiza_resultado(tuplas_pilotos,dicionarios_ordenados)


mostra_dados("Quantidade de vitório por piloto","race_summaries.csv",quantidade_de_vitorias_piloto)
# Out:
# |___    Quantidade de vitório por piloto   ___|
# ('Alain Prost', 51)
# ('Alan Jones', 12)
# ('Alberto Ascari', 13)
# ('Alessandro Nannini', 1)
# ('Ayrton Senna', 41)
# ('Bill Vukovich', 2)
# ('Bob Sweikert', 1)
# ('Bruce McLaren', 4)
# ('Carlos Pace', 1)
# ('Carlos Reutemann', 12)
# ('Carlos Sainz', 1)
# ('Charles Leclerc', 5)
# ('Clay Regazzoni', 5)
# ('Damon Hill', 22)
# ('Dan Gurney', 4)
# ('Daniel Ricciardo', 8)
# ('David Coulthard', 13)
# ('Denny Hulme', 8)
# ('Didier Pironi', 3)
# ('Eddie Irvine', 4)
# ('Elio de Angelis', 2)
# ('Emerson Fittipaldi', 14)
# ('Esteban Ocon', 1)
# ('Felipe Massa', 11)
# ('Fernando Alonso', 32)
# ('Francois Cevert', 1)
# ('George Russell', 1)
# ('Gerhard Berger', 10)
# ('Giancarlo Baghetti', 1)
# ('Giancarlo Fisichella', 3)
# ('Gilles Villeneuve', 6)
# ('Graham Hill', 14)
# ('Gunnar Nilsson', 1)
# ('Heikki Kovalainen', 1)
# ('Heinz-Harald Frentzen', 3)
# ('Innes Ireland', 1)
# ('Jack Brabham', 14)
# ('Jackie Stewart', 27)
# ('Jacky Ickx', 8)
# ('Jacques Laffite', 6)
# ('Jacques Villeneuve', 11)
# ('James Hunt', 10)
# ('Jarno Trulli', 1)
# ('Jean Alesi', 1)
# ('Jean-Pierre Beltoise', 1)
# ('Jean-Pierre Jabouille', 2)
# ('Jenson Button', 15)
# ('Jim Clark', 25)
# ('Jim Rathmann', 1)
# ('Jimmy Bryan', 1)
# ('Jo Bonnier', 1)
# ('Jo Siffert', 2)
# ('Jochen Mass', 1)
# ('Jochen Rindt', 6)
# ('Jody Scheckter', 10)
# ('John Surtees', 6)
# ('John Watson', 5)
# ('Johnnie Parsons', 1)
# ('Johnny Herbert', 3)
# ('Jose Froilan Gonzalez', 2)
# ('Juan Manuel Fangio', 24)
# ('Juan Pablo Montoya', 7)
# ('Keke Rosberg', 5)
# ('Kimi Räikkönen', 21)
# ('Lee Wallard', 1)
# ('Lewis Hamilton', 103)
# ('Lorenzo Bandini', 1)
# ('Ludovico Scarfiotti', 1)
# ('Luigi Fagioli', 1)
# ('Luigi Musso', 1)
# ('Mario Andretti', 12)
# ('Mark Webber', 9)
# ('Maurice Trintignant', 2)
# ('Max Verstappen', 35)
# ('Michael Schumacher', 91)
# ('Michele Alboreto', 5)
# ('Mika Hakkinen', 20)
# ('Mike Hawthorn', 3)
# ('Nelson Piquet', 23)
# ('Nico Rosberg', 23)
# ('Nigel Mansell', 31)
# ('Niki Lauda', 25)
# ('Nino Farina', 5)
# ('Olivier Panis', 1)
# ('Pastor Maldonado', 1)
# ('Pat Flaherty', 1)
# ('Patrick Depailler', 2)
# ('Patrick Tambay', 2)
# ('Pedro Rodriguez', 2)
# ('Peter Collins', 3)
# ('Peter Gethin', 1)
# ('Peter Revson', 2)
# ('Phil Hill', 3)
# ('Piero Taruffi', 1)
# ('Pierre Gasly', 1)
# ('Ralf Schumacher', 6)
# ('Rene Arnoux', 7)
# ('Riccardo Patrese', 6)
# ('Richie Ginther', 1)
# ('Robert Kubica', 1)
# ('Rodger Ward', 1)
# ('Ronnie Peterson', 10)
# ('Rubens Barrichello', 11)
# ('Sam Hanks', 1)
# ('Sebastian Vettel', 53)
# ('Sergio Perez', 4)
# ('Stirling Moss', 16)
# ('Thierry Boutsen', 3)
# ('Tony Brooks', 6)
# ('Troy Ruttman', 1)
# ('Valtteri Bottas', 10)
# ('Vittorio Brambilla', 1)
# ('Wolfgang von Trips', 2)

# %% [markdown]
# **2. Escreva uma ou mais funções do paradigma funcional, cujo o objetivo desta tarefa é ler os dados do arquivo "driver_standings.csv" para extrair a nacionalidade de cada piloto e adicionar este campo nos dados do arquivo  "race_summaries.csv".**
#
# - **Para testar, é necessário usar a função auxiliar `mostra_dados` confirme apresentado abaixo.**
# ```python
# mostra_dados("adicionar_nacionalidade_de_piloto_em_race_summaries", "race_summaries.csv", adicionar_nacionalidade_de_piloto_em_race_summaries)
# ```
#
# - **Para persistir o resultado em disco, é necessário usar a função auxiliar `salvar_dados` conforme apresentado abaixo.**
# ```python
# salvar_dados("race_summaries.csv", "race_summaries+nacionalidade.csv", adicionar_nacionalidade_de_piloto)
# ```
#
# - **Exemplo de saída esperada:**
# ```bash
# |___    adicionar_nacionalidade_de_piloto   ___|
# {'Grand Prix': 'Great Britain', 'Date': '13 May 1950', 'Winner': 'Nino Farina', 'Car': 'Alfa Romeo', 'Laps': '70.0', 'Time': '2:13:23.600', 'WinnerCode': 'FAR', 'Year': '1950', 'Nationality': 'ITA'}
# {'Grand Prix': 'Monaco', 'Date': '21 May 1950', 'Winner': 'Juan Manuel Fangio', 'Car': 'Alfa Romeo', 'Laps': '100.0', 'Time': '3:13:18.700', 'WinnerCode': 'FAN', 'Year': '1950', 'Nationality': 'ARG'}
# {'Grand Prix': 'Indianapolis 500', 'Date': '30 May 1950', 'Winner': 'Johnnie Parsons', 'Car': 'Kurtis Kraft Offenhauser', 'Laps': '138.0', 'Time': '2:46:55.970', 'WinnerCode': 'PAR', 'Year': '1950', 'Nationality': 'USA'}
# {'Grand Prix': 'Switzerland', 'Date': '04 Jun 1950', 'Winner': 'Nino Farina', 'Car': 'Alfa Romeo', 'Laps': '42.0', 'Time': '2:02:53.700', 'WinnerCode': 'FAR', 'Year': '1950', 'Nationality': 'ITA'}
# {'Grand Prix': 'Belgium', 'Date': '18 Jun 1950', 'Winner': 'Juan Manuel Fangio', 'Car': 'Alfa Romeo', 'Laps': '35.0', 'Time': '2:47:26.000', 'WinnerCode': 'FAN', 'Year': '1950', 'Nationality': 'ARG'}
# {'Grand Prix': 'France', 'Date': '02 Jul 1950', 'Winner': 'Juan Manuel Fangio', 'Car': 'Alfa Romeo', 'Laps': '64.0', 'Time': '2:57:52.800', 'WinnerCode': 'FAN', 'Year': '1950', 'Nationality': 'ARG'}
# {'Grand Prix': 'Italy', 'Date': '03 Sep 1950', 'Winner': 'Nino Farina', 'Car': 'Alfa Romeo', 'Laps': '80.0', 'Time': '2:51:17.400', 'WinnerCode': 'FAR', 'Year': '1950', 'Nationality': 'ITA'}
# ...
# ```

# %%
def retorna_lista_drivers(iteravel): #Retorna uma lista com os nomes dos pilotos.
    if iteravel[1:] == []:
        return []
    else:
        return [iteravel[0]["Driver"]] + retorna_lista_drivers(iteravel[1:])

def retorna_lista_nacionalidade(iteravel): #Retorna uma lista com as nacionalidades dos pilotos.
    if iteravel[1:] == []:
        return []
    else:
        return [iteravel[0]["Nationality"]] + retorna_lista_nacionalidade(iteravel[1:])


def adiciona_nacionalidade_de_piloto_em_race_summaries(iterador): #Função principal que organiza tudo e chama outras funções.
    dados_driver = sorted(retorna_dados("driver_standings.csv"),key=lambda dicionario: dicionario["Driver"]) #Salva na variável dados_driver ordenados por nome, os dicionários de retornados pela função retorna_dados, aplicados no arquivo "driver_standings.csv".
    dados_race_summaries = sorted(iterador,key=lambda dicionario: dicionario["Winner"]) #Salva na variável dados_race_summaries ordenados por nome, os dicionários retornados do arquivo "race_summaries.csv".
    lista_nacionalidades = retorna_lista_nacionalidade(dados_driver) #Salva lista com o nome dos pilotos em uma variável.
    lista_nome_pilotos = retorna_lista_drivers(dados_driver) #Salva lista com as nacionalidades dos pilotos em uma variável.
    lista_zip = dict(zip(lista_nome_pilotos,lista_nacionalidades)) #"Zipa" os elementos de cada lista do mesmo índice, e depois transforma em dicionário.
    def organiza_nacionalidade(dicionario): #Função que guarda em aux a nacionalidade do piloto, e cria uma nova chave nacionalidade no dicionário recebido como argumento, e retorna o mesmo.
        aux = lista_zip[dicionario["Winner"]]
        dicionario["Nationality"] = aux
        return dicionario
    return list(map(organiza_nacionalidade,dados_race_summaries))



mostra_dados("Adiciona_nacionalidade_de_piloto","race_summaries.csv",adiciona_nacionalidade_de_piloto_em_race_summaries) 
#Não salvei o resultado, pois não sabia se era para fazê-lo.
# Out:
# |___    Adiciona_nacionalidade_de_piloto   ___|
# {'Grand Prix': 'France', 'Date': '05 Jul 1981', 'Winner': 'Alain Prost', 'Car': 'Renault', 'Laps': '80.0', 'Time': '1:35:48.130', 'WinnerCode': 'PRO', 'Year': '1981', 'Nationality': 'FRA'}
# {'Grand Prix': 'Netherlands', 'Date': '30 Aug 1981', 'Winner': 'Alain Prost', 'Car': 'Renault', 'Laps': '72.0', 'Time': '1:40:22.430', 'WinnerCode': 'PRO', 'Year': '1981', 'Nationality': 'FRA'}
# {'Grand Prix': 'Italy', 'Date': '13 Sep 1981', 'Winner': 'Alain Prost', 'Car': 'Renault', 'Laps': '52.0', 'Time': '1:26:33.897', 'WinnerCode': 'PRO', 'Year': '1981', 'Nationality': 'FRA'}
# {'Grand Prix': 'South Africa', 'Date': '23 Jan 1982', 'Winner': 'Alain Prost', 'Car': 'Renault', 'Laps': '77.0', 'Time': '1:32:08.401', 'WinnerCode': 'PRO', 'Year': '1982', 'Nationality': 'FRA'}
# {'Grand Prix': 'Brazil', 'Date': '21 Mar 1982', 'Winner': 'Alain Prost', 'Car': 'Renault', 'Laps': '63.0', 'Time': '1:44:33.134', 'WinnerCode': 'PRO', 'Year': '1982', 'Nationality': 'FRA'}
# {'Grand Prix': 'France', 'Date': '17 Apr 1983', 'Winner': 'Alain Prost', 'Car': 'Renault', 'Laps': '54.0', 'Time': '1:34:13.913', 'WinnerCode': 'PRO', 'Year': '1983', 'Nationality': 'FRA'}
# {'Grand Prix': 'Belgium', 'Date': '22 May 1983', 'Winner': 'Alain Prost', 'Car': 'Renault', 'Laps': '40.0', 'Time': '1:27:11.502', 'WinnerCode': 'PRO', 'Year': '1983', 'Nationality': 'FRA'}
# {'Grand Prix': 'Great Britain', 'Date': '16 Jul 1983', 'Winner': 'Alain Prost', 'Car': 'Renault', 'Laps': '67.0', 'Time': '1:24:39.780', 'WinnerCode': 'PRO', 'Year': '1983', 'Nationality': 'FRA'}
# {'Grand Prix': 'Austria', 'Date': '14 Aug 1983', 'Winner': 'Alain Prost', 'Car': 'Renault', 'Laps': '53.0', 'Time': '1:24:32.745', 'WinnerCode': 'PRO', 'Year': '1983', 'Nationality': 'FRA'}
# {'Grand Prix': 'Brazil', 'Date': '25 Mar 1984', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '61.0', 'Time': '1:42:34.492', 'WinnerCode': 'PRO', 'Year': '1984', 'Nationality': 'FRA'}
# {'Grand Prix': 'San Marino', 'Date': '06 May 1984', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '60.0', 'Time': '1:36:53.679', 'WinnerCode': 'PRO', 'Year': '1984', 'Nationality': 'FRA'}
# {'Grand Prix': 'Monaco', 'Date': '03 Jun 1984', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '31.0', 'Time': '1:01:07.740', 'WinnerCode': 'PRO', 'Year': '1984', 'Nationality': 'FRA'}
# {'Grand Prix': 'Germany', 'Date': '05 Aug 1984', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '44.0', 'Time': '1:24:43.210', 'WinnerCode': 'PRO', 'Year': '1984', 'Nationality': 'FRA'}
# {'Grand Prix': 'Netherlands', 'Date': '26 Aug 1984', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '71.0', 'Time': '1:37:21.468', 'WinnerCode': 'PRO', 'Year': '1984', 'Nationality': 'FRA'}
# {'Grand Prix': 'Europe', 'Date': '07 Oct 1984', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '67.0', 'Time': '1:35:13.284', 'WinnerCode': 'PRO', 'Year': '1984', 'Nationality': 'FRA'}
# {'Grand Prix': 'Portugal', 'Date': '21 Oct 1984', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '70.0', 'Time': '1:41:11.753', 'WinnerCode': 'PRO', 'Year': '1984', 'Nationality': 'FRA'}
# {'Grand Prix': 'Brazil', 'Date': '07 Apr 1985', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '61.0', 'Time': '1:41:26.115', 'WinnerCode': 'PRO', 'Year': '1985', 'Nationality': 'FRA'}
# {'Grand Prix': 'Monaco', 'Date': '19 May 1985', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '78.0', 'Time': '1:51:58.034', 'WinnerCode': 'PRO', 'Year': '1985', 'Nationality': 'FRA'}
# {'Grand Prix': 'Great Britain', 'Date': '21 Jul 1985', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '65.0', 'Time': '1:18:10.436', 'WinnerCode': 'PRO', 'Year': '1985', 'Nationality': 'FRA'}
# {'Grand Prix': 'Austria', 'Date': '18 Aug 1985', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '52.0', 'Time': '1:20:12.583', 'WinnerCode': 'PRO', 'Year': '1985', 'Nationality': 'FRA'}
# {'Grand Prix': 'Italy', 'Date': '08 Sep 1985', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '51.0', 'Time': '1:17:59.451', 'WinnerCode': 'PRO', 'Year': '1985', 'Nationality': 'FRA'}
# {'Grand Prix': 'San Marino', 'Date': '27 Apr 1986', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '60.0', 'Time': '1:32:28.408', 'WinnerCode': 'PRO', 'Year': '1986', 'Nationality': 'FRA'}
# {'Grand Prix': 'Monaco', 'Date': '11 May 1986', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '78.0', 'Time': '1:55:41.060', 'WinnerCode': 'PRO', 'Year': '1986', 'Nationality': 'FRA'}
# {'Grand Prix': 'Austria', 'Date': '17 Aug 1986', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '52.0', 'Time': '1:21:22.531', 'WinnerCode': 'PRO', 'Year': '1986', 'Nationality': 'FRA'}
# {'Grand Prix': 'Australia', 'Date': '26 Oct 1986', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '82.0', 'Time': '1:54:20.388', 'WinnerCode': 'PRO', 'Year': '1986', 'Nationality': 'FRA'}
# {'Grand Prix': 'Brazil', 'Date': '12 Apr 1987', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '61.0', 'Time': '1:39:45.141', 'WinnerCode': 'PRO', 'Year': '1987', 'Nationality': 'FRA'}
# {'Grand Prix': 'Belgium', 'Date': '17 May 1987', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '43.0', 'Time': '1:27:03.217', 'WinnerCode': 'PRO', 'Year': '1987', 'Nationality': 'FRA'}
# {'Grand Prix': 'Portugal', 'Date': '20 Sep 1987', 'Winner': 'Alain Prost', 'Car': 'McLaren TAG', 'Laps': '70.0', 'Time': '1:37:03.906', 'WinnerCode': 'PRO', 'Year': '1987', 'Nationality': 'FRA'}
# {'Grand Prix': 'Brazil', 'Date': '03 Apr 1988', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '60.0', 'Time': '1:36:06.857', 'WinnerCode': 'PRO', 'Year': '1988', 'Nationality': 'FRA'}
# {'Grand Prix': 'Monaco', 'Date': '15 May 1988', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '78.0', 'Time': '1:57:17.077', 'WinnerCode': 'PRO', 'Year': '1988', 'Nationality': 'FRA'}
# {'Grand Prix': 'Mexico', 'Date': '29 May 1988', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '67.0', 'Time': '1:30:15.737', 'WinnerCode': 'PRO', 'Year': '1988', 'Nationality': 'FRA'}
# {'Grand Prix': 'France', 'Date': '03 Jul 1988', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '80.0', 'Time': '1:37:37.328', 'WinnerCode': 'PRO', 'Year': '1988', 'Nationality': 'FRA'}
# {'Grand Prix': 'Portugal', 'Date': '25 Sep 1988', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '70.0', 'Time': '1:37:40.958', 'WinnerCode': 'PRO', 'Year': '1988', 'Nationality': 'FRA'}
# {'Grand Prix': 'Spain', 'Date': '02 Oct 1988', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '72.0', 'Time': '1:48:43.851', 'WinnerCode': 'PRO', 'Year': '1988', 'Nationality': 'FRA'}
# {'Grand Prix': 'Australia', 'Date': '13 Nov 1988', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '82.0', 'Time': '1:53:14.676', 'WinnerCode': 'PRO', 'Year': '1988', 'Nationality': 'FRA'}
# {'Grand Prix': 'United States', 'Date': '04 Jun 1989', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '75.0', 'Time': '2:01:33.133', 'WinnerCode': 'PRO', 'Year': '1989', 'Nationality': 'FRA'}
# {'Grand Prix': 'France', 'Date': '09 Jul 1989', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '80.0', 'Time': '1:38:29.411', 'WinnerCode': 'PRO', 'Year': '1989', 'Nationality': 'FRA'}
# {'Grand Prix': 'Great Britain', 'Date': '16 Jul 1989', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '64.0', 'Time': '1:19:22.131', 'WinnerCode': 'PRO', 'Year': '1989', 'Nationality': 'FRA'}
# {'Grand Prix': 'Italy', 'Date': '10 Sep 1989', 'Winner': 'Alain Prost', 'Car': 'McLaren Honda', 'Laps': '53.0', 'Time': '1:19:27.550', 'WinnerCode': 'PRO', 'Year': '1989', 'Nationality': 'FRA'}
# {'Grand Prix': 'Brazil', 'Date': '25 Mar 1990', 'Winner': 'Alain Prost', 'Car': 'Ferrari', 'Laps': '71.0', 'Time': '1:37:21.258', 'WinnerCode': 'PRO', 'Year': '1990', 'Nationality': 'FRA'}
# {'Grand Prix': 'Mexico', 'Date': '24 Jun 1990', 'Winner': 'Alain Prost', 'Car': 'Ferrari', 'Laps': '69.0', 'Time': '1:32:35.783', 'WinnerCode': 'PRO', 'Year': '1990', 'Nationality': 'FRA'}
# {'Grand Prix': 'France', 'Date': '08 Jul 1990', 'Winner': 'Alain Prost', 'Car': 'Ferrari', 'Laps': '80.0', 'Time': '1:33:29.606', 'WinnerCode': 'PRO', 'Year': '1990', 'Nationality': 'FRA'}
# {'Grand Prix': 'Great Britain', 'Date': '15 Jul 1990', 'Winner': 'Alain Prost', 'Car': 'Ferrari', 'Laps': '64.0', 'Time': '1:18:30.999', 'WinnerCode': 'PRO', 'Year': '1990', 'Nationality': 'FRA'}
# {'Grand Prix': 'Spain', 'Date': '30 Sep 1990', 'Winner': 'Alain Prost', 'Car': 'Ferrari', 'Laps': '73.0', 'Time': '1:48:01.461', 'WinnerCode': 'PRO', 'Year': '1990', 'Nationality': 'FRA'}
# {'Grand Prix': 'South Africa', 'Date': '14 Mar 1993', 'Winner': 'Alain Prost', 'Car': 'Williams Renault', 'Laps': '72.0', 'Time': '1:38:45.082', 'WinnerCode': 'PRO', 'Year': '1993', 'Nationality': 'FRA'}
# {'Grand Prix': 'San Marino', 'Date': '25 Apr 1993', 'Winner': 'Alain Prost', 'Car': 'Williams Renault', 'Laps': '61.0', 'Time': '1:33:20.413', 'WinnerCode': 'PRO', 'Year': '1993', 'Nationality': 'FRA'}
# {'Grand Prix': 'Spain', 'Date': '09 May 1993', 'Winner': 'Alain Prost', 'Car': 'Williams Renault', 'Laps': '65.0', 'Time': '1:32:27.685', 'WinnerCode': 'PRO', 'Year': '1993', 'Nationality': 'FRA'}
# {'Grand Prix': 'Canada', 'Date': '13 Jun 1993', 'Winner': 'Alain Prost', 'Car': 'Williams Renault', 'Laps': '69.0', 'Time': '1:36:41.822', 'WinnerCode': 'PRO', 'Year': '1993', 'Nationality': 'FRA'}
# {'Grand Prix': 'France', 'Date': '04 Jul 1993', 'Winner': 'Alain Prost', 'Car': 'Williams Renault', 'Laps': '72.0', 'Time': '1:38:35.241', 'WinnerCode': 'PRO', 'Year': '1993', 'Nationality': 'FRA'}
# {'Grand Prix': 'Great Britain', 'Date': '11 Jul 1993', 'Winner': 'Alain Prost', 'Car': 'Williams Renault', 'Laps': '59.0', 'Time': '1:25:38.189', 'WinnerCode': 'PRO', 'Year': '1993', 'Nationality': 'FRA'}
# {'Grand Prix': 'Germany', 'Date': '25 Jul 1993', 'Winner': 'Alain Prost', 'Car': 'Williams Renault', 'Laps': '45.0', 'Time': '1:18:40.885', 'WinnerCode': 'PRO', 'Year': '1993', 'Nationality': 'FRA'}
# {'Grand Prix': 'Austria', 'Date': '14 Aug 1977', 'Winner': 'Alan Jones', 'Car': 'Shadow Ford', 'Laps': '54.0', 'Time': '1:37:16.490', 'WinnerCode': 'JON', 'Year': '1977', 'Nationality': 'AUS'}
# {'Grand Prix': 'Germany', 'Date': '29 Jul 1979', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '45.0', 'Time': '1:24:48.830', 'WinnerCode': 'JON', 'Year': '1979', 'Nationality': 'AUS'}
# {'Grand Prix': 'Austria', 'Date': '12 Aug 1979', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '54.0', 'Time': '1:27:38.010', 'WinnerCode': 'JON', 'Year': '1979', 'Nationality': 'AUS'}
# {'Grand Prix': 'Netherlands', 'Date': '26 Aug 1979', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '75.0', 'Time': '1:41:19.775', 'WinnerCode': 'JON', 'Year': '1979', 'Nationality': 'AUS'}
# {'Grand Prix': 'Canada', 'Date': '30 Sep 1979', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '72.0', 'Time': '1:52:06.892', 'WinnerCode': 'JON', 'Year': '1979', 'Nationality': 'AUS'}
# {'Grand Prix': 'Argentina', 'Date': '13 Jan 1980', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '53.0', 'Time': '1:43:24.380', 'WinnerCode': 'JON', 'Year': '1980', 'Nationality': 'AUS'}
# {'Grand Prix': 'France', 'Date': '29 Jun 1980', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '54.0', 'Time': '1:32:43.420', 'WinnerCode': 'JON', 'Year': '1980', 'Nationality': 'AUS'}
# {'Grand Prix': 'Great Britain', 'Date': '13 Jul 1980', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '76.0', 'Time': '1:34:49.228', 'WinnerCode': 'JON', 'Year': '1980', 'Nationality': 'AUS'}
# {'Grand Prix': 'Canada', 'Date': '28 Sep 1980', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '70.0', 'Time': '1:46:45.530', 'WinnerCode': 'JON', 'Year': '1980', 'Nationality': 'AUS'}
# {'Grand Prix': 'USA East', 'Date': '05 Oct 1980', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '59.0', 'Time': '1:34:36.050', 'WinnerCode': 'JON', 'Year': '1980', 'Nationality': 'AUS'}
# {'Grand Prix': 'USA West', 'Date': '15 Mar 1981', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '80.0', 'Time': '1:50:41.330', 'WinnerCode': 'JON', 'Year': '1981', 'Nationality': 'AUS'}
# {'Grand Prix': 'Las Vegas', 'Date': '17 Oct 1981', 'Winner': 'Alan Jones', 'Car': 'Williams Ford', 'Laps': '75.0', 'Time': '1:44:09.077', 'WinnerCode': 'JON', 'Year': '1981', 'Nationality': 'AUS'}
# {'Grand Prix': 'Germany', 'Date': '29 Jul 1951', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '20.0', 'Time': '3:23:03.300', 'WinnerCode': 'ASC', 'Year': '1951', 'Nationality': 'ITA'}
# {'Grand Prix': 'Italy', 'Date': '16 Sep 1951', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '80.0', 'Time': '2:42:39.300', 'WinnerCode': 'ASC', 'Year': '1951', 'Nationality': 'ITA'}
# {'Grand Prix': 'Belgium', 'Date': '22 Jun 1952', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '36.0', 'Time': '3:03:46.300', 'WinnerCode': 'ASC', 'Year': '1952', 'Nationality': 'ITA'}
# {'Grand Prix': 'France', 'Date': '06 Jul 1952', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '77.0', 'Time': '3:00:00.000', 'WinnerCode': 'ASC', 'Year': '1952', 'Nationality': 'ITA'}
# {'Grand Prix': 'Great Britain', 'Date': '19 Jul 1952', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '85.0', 'Time': '2:44:11.000', 'WinnerCode': 'ASC', 'Year': '1952', 'Nationality': 'ITA'}
# {'Grand Prix': 'Germany', 'Date': '03 Aug 1952', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '18.0', 'Time': '3:06:13.300', 'WinnerCode': 'ASC', 'Year': '1952', 'Nationality': 'ITA'}
# {'Grand Prix': 'Netherlands', 'Date': '17 Aug 1952', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '90.0', 'Time': '2:53:28.500', 'WinnerCode': 'ASC', 'Year': '1952', 'Nationality': 'ITA'}
# {'Grand Prix': 'Italy', 'Date': '07 Sep 1952', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '80.0', 'Time': '2:50:45.600', 'WinnerCode': 'ASC', 'Year': '1952', 'Nationality': 'ITA'}
# {'Grand Prix': 'Argentina', 'Date': '18 Jan 1953', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '97.0', 'Time': '3:01:04.600', 'WinnerCode': 'ASC', 'Year': '1953', 'Nationality': 'ITA'}
# {'Grand Prix': 'Netherlands', 'Date': '07 Jun 1953', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '90.0', 'Time': '2:53:35.800', 'WinnerCode': 'ASC', 'Year': '1953', 'Nationality': 'ITA'}
# {'Grand Prix': 'Belgium', 'Date': '21 Jun 1953', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '36.0', 'Time': '2:48:30.300', 'WinnerCode': 'ASC', 'Year': '1953', 'Nationality': 'ITA'}
# {'Grand Prix': 'Great Britain', 'Date': '18 Jul 1953', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '90.0', 'Time': '2:50:00.000', 'WinnerCode': 'ASC', 'Year': '1953', 'Nationality': 'ITA'}
# {'Grand Prix': 'Switzerland', 'Date': '23 Aug 1953', 'Winner': 'Alberto Ascari', 'Car': 'Ferrari', 'Laps': '65.0', 'Time': '3:01:34.400', 'WinnerCode': 'ASC', 'Year': '1953', 'Nationality': 'ITA'}
# {'Grand Prix': 'Japan', 'Date': '22 Oct 1989', 'Winner': 'Alessandro Nannini', 'Car': 'Benetton Ford', 'Laps': '53.0', 'Time': '1:35:06.277', 'WinnerCode': 'NAN', 'Year': '1989', 'Nationality': 'ITA'}
# {'Grand Prix': 'Portugal', 'Date': '21 Apr 1985', 'Winner': 'Ayrton Senna', 'Car': 'Lotus Renault', 'Laps': '67.0', 'Time': '2:00:28.006', 'WinnerCode': 'SEN', 'Year': '1985', 'Nationality': 'BRA'}
# {'Grand Prix': 'Belgium', 'Date': '15 Sep 1985', 'Winner': 'Ayrton Senna', 'Car': 'Lotus Renault', 'Laps': '43.0', 'Time': '1:34:19.893', 'WinnerCode': 'SEN', 'Year': '1985', 'Nationality': 'BRA'}
# {'Grand Prix': 'Spain', 'Date': '13 Apr 1986', 'Winner': 'Ayrton Senna', 'Car': 'Lotus Renault', 'Laps': '72.0', 'Time': '1:48:47.735', 'WinnerCode': 'SEN', 'Year': '1986', 'Nationality': 'BRA'}
# {'Grand Prix': 'Detroit', 'Date': '22 Jun 1986', 'Winner': 'Ayrton Senna', 'Car': 'Lotus Renault', 'Laps': '63.0', 'Time': '1:51:12.847', 'WinnerCode': 'SEN', 'Year': '1986', 'Nationality': 'BRA'}
# {'Grand Prix': 'Monaco', 'Date': '31 May 1987', 'Winner': 'Ayrton Senna', 'Car': 'Lotus Honda', 'Laps': '78.0', 'Time': '1:57:54.085', 'WinnerCode': 'SEN', 'Year': '1987', 'Nationality': 'BRA'}
# {'Grand Prix': 'Detroit', 'Date': '21 Jun 1987', 'Winner': 'Ayrton Senna', 'Car': 'Lotus Honda', 'Laps': '63.0', 'Time': '1:50:16.358', 'WinnerCode': 'SEN', 'Year': '1987', 'Nationality': 'BRA'}
# {'Grand Prix': 'San Marino', 'Date': '01 May 1988', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '60.0', 'Time': '1:32:41.264', 'WinnerCode': 'SEN', 'Year': '1988', 'Nationality': 'BRA'}
# {'Grand Prix': 'Canada', 'Date': '12 Jun 1988', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '69.0', 'Time': '1:39:46.618', 'WinnerCode': 'SEN', 'Year': '1988', 'Nationality': 'BRA'}
# {'Grand Prix': 'Detroit', 'Date': '19 Jun 1988', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '63.0', 'Time': '1:54:56.035', 'WinnerCode': 'SEN', 'Year': '1988', 'Nationality': 'BRA'}
# {'Grand Prix': 'Great Britain', 'Date': '10 Jul 1988', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '65.0', 'Time': '1:33:16.367', 'WinnerCode': 'SEN', 'Year': '1988', 'Nationality': 'BRA'}
# {'Grand Prix': 'Germany', 'Date': '24 Jul 1988', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '44.0', 'Time': '1:32:54.188', 'WinnerCode': 'SEN', 'Year': '1988', 'Nationality': 'BRA'}
# {'Grand Prix': 'Hungary', 'Date': '07 Aug 1988', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '76.0', 'Time': '1:57:47.081', 'WinnerCode': 'SEN', 'Year': '1988', 'Nationality': 'BRA'}
# {'Grand Prix': 'Belgium', 'Date': '28 Aug 1988', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '43.0', 'Time': '1:28:00.549', 'WinnerCode': 'SEN', 'Year': '1988', 'Nationality': 'BRA'}
# {'Grand Prix': 'Japan', 'Date': '30 Oct 1988', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '51.0', 'Time': '1:33:26.173', 'WinnerCode': 'SEN', 'Year': '1988', 'Nationality': 'BRA'}
# {'Grand Prix': 'San Marino', 'Date': '23 Apr 1989', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '58.0', 'Time': '1:26:51.245', 'WinnerCode': 'SEN', 'Year': '1989', 'Nationality': 'BRA'}
# {'Grand Prix': 'Monaco', 'Date': '07 May 1989', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '77.0', 'Time': '1:53:33.251', 'WinnerCode': 'SEN', 'Year': '1989', 'Nationality': 'BRA'}
# {'Grand Prix': 'Mexico', 'Date': '28 May 1989', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '69.0', 'Time': '1:35:21.431', 'WinnerCode': 'SEN', 'Year': '1989', 'Nationality': 'BRA'}
# {'Grand Prix': 'Germany', 'Date': '30 Jul 1989', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '45.0', 'Time': '1:21:43.302', 'WinnerCode': 'SEN', 'Year': '1989', 'Nationality': 'BRA'}
# {'Grand Prix': 'Belgium', 'Date': '27 Aug 1989', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '44.0', 'Time': '1:40:54.196', 'WinnerCode': 'SEN', 'Year': '1989', 'Nationality': 'BRA'}
# {'Grand Prix': 'Spain', 'Date': '01 Oct 1989', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '72.0', 'Time': '1:47:48.264', 'WinnerCode': 'SEN', 'Year': '1989', 'Nationality': 'BRA'}
# {'Grand Prix': 'United States', 'Date': '11 Mar 1990', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '72.0', 'Time': '1:52:32.829', 'WinnerCode': 'SEN', 'Year': '1990', 'Nationality': 'BRA'}
# {'Grand Prix': 'Monaco', 'Date': '27 May 1990', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '78.0', 'Time': '1:52:46.982', 'WinnerCode': 'SEN', 'Year': '1990', 'Nationality': 'BRA'}
# {'Grand Prix': 'Canada', 'Date': '10 Jun 1990', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '70.0', 'Time': '1:42:56.400', 'WinnerCode': 'SEN', 'Year': '1990', 'Nationality': 'BRA'}
# {'Grand Prix': 'Germany', 'Date': '29 Jul 1990', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '45.0', 'Time': '1:20:47.164', 'WinnerCode': 'SEN', 'Year': '1990', 'Nationality': 'BRA'}
# {'Grand Prix': 'Belgium', 'Date': '26 Aug 1990', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '44.0', 'Time': '1:26:31.997', 'WinnerCode': 'SEN', 'Year': '1990', 'Nationality': 'BRA'}
# {'Grand Prix': 'Italy', 'Date': '09 Sep 1990', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '53.0', 'Time': '1:17:57.878', 'WinnerCode': 'SEN', 'Year': '1990', 'Nationality': 'BRA'}
# {'Grand Prix': 'United States', 'Date': '10 Mar 1991', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '81.0', 'Time': '2:00:47.828', 'WinnerCode': 'SEN', 'Year': '1991', 'Nationality': 'BRA'}
# {'Grand Prix': 'Brazil', 'Date': '24 Mar 1991', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '71.0', 'Time': '1:38:28.128', 'WinnerCode': 'SEN', 'Year': '1991', 'Nationality': 'BRA'}
# {'Grand Prix': 'San Marino', 'Date': '28 Apr 1991', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '61.0', 'Time': '1:35:14.750', 'WinnerCode': 'SEN', 'Year': '1991', 'Nationality': 'BRA'}
# {'Grand Prix': 'Monaco', 'Date': '12 May 1991', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '78.0', 'Time': '1:53:02.334', 'WinnerCode': 'SEN', 'Year': '1991', 'Nationality': 'BRA'}
# {'Grand Prix': 'Hungary', 'Date': '11 Aug 1991', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '77.0', 'Time': '1:49:12.796', 'WinnerCode': 'SEN', 'Year': '1991', 'Nationality': 'BRA'}
# {'Grand Prix': 'Belgium', 'Date': '25 Aug 1991', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '44.0', 'Time': '1:27:17.669', 'WinnerCode': 'SEN', 'Year': '1991', 'Nationality': 'BRA'}
# {'Grand Prix': 'Australia', 'Date': '03 Nov 1991', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '14.0', 'Time': '24:34.899', 'WinnerCode': 'SEN', 'Year': '1991', 'Nationality': 'BRA'}
# {'Grand Prix': 'Monaco', 'Date': '31 May 1992', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '78.0', 'Time': '1:50:59.372', 'WinnerCode': 'SEN', 'Year': '1992', 'Nationality': 'BRA'}
# {'Grand Prix': 'Hungary', 'Date': '16 Aug 1992', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '77.0', 'Time': '1:46:19.216', 'WinnerCode': 'SEN', 'Year': '1992', 'Nationality': 'BRA'}
# {'Grand Prix': 'Italy', 'Date': '13 Sep 1992', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Honda', 'Laps': '53.0', 'Time': '1:18:15.349', 'WinnerCode': 'SEN', 'Year': '1992', 'Nationality': 'BRA'}
# {'Grand Prix': 'Brazil', 'Date': '28 Mar 1993', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Ford', 'Laps': '71.0', 'Time': '1:51:15.485', 'WinnerCode': 'SEN', 'Year': '1993', 'Nationality': 'BRA'}
# {'Grand Prix': 'Europe', 'Date': '11 Apr 1993', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Ford', 'Laps': '76.0', 'Time': '1:50:46.570', 'WinnerCode': 'SEN', 'Year': '1993', 'Nationality': 'BRA'}
# {'Grand Prix': 'Monaco', 'Date': '23 May 1993', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Ford', 'Laps': '78.0', 'Time': '1:52:10.947', 'WinnerCode': 'SEN', 'Year': '1993', 'Nationality': 'BRA'}
# {'Grand Prix': 'Japan', 'Date': '24 Oct 1993', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Ford', 'Laps': '53.0', 'Time': '1:40:27.912', 'WinnerCode': 'SEN', 'Year': '1993', 'Nationality': 'BRA'}
# {'Grand Prix': 'Australia', 'Date': '07 Nov 1993', 'Winner': 'Ayrton Senna', 'Car': 'McLaren Ford', 'Laps': '79.0', 'Time': '1:43:27.476', 'WinnerCode': 'SEN', 'Year': '1993', 'Nationality': 'BRA'}
# {'Grand Prix': 'Indianapolis 500', 'Date': '30 May 1953', 'Winner': 'Bill Vukovich', 'Car': 'Kurtis Kraft Offenhauser', 'Laps': '200.0', 'Time': '3:53:01.690', 'WinnerCode': 'VUK', 'Year': '1953', 'Nationality': 'USA'}
# {'Grand Prix': 'Indianapolis 500', 'Date': '31 May 1954', 'Winner': 'Bill Vukovich', 'Car': 'Kurtis Kraft Offenhauser', 'Laps': '200.0', 'Time': '3:49:17.270', 'WinnerCode': 'VUK', 'Year': '1954', 'Nationality': 'USA'}
# {'Grand Prix': 'Indianapolis 500', 'Date': '30 May 1955', 'Winner': 'Bob Sweikert', 'Car': 'Kurtis Kraft Offenhauser', 'Laps': '200.0', 'Time': '3:53:59.530', 'WinnerCode': 'SWE', 'Year': '1955', 'Nationality': 'USA'}
# {'Grand Prix': 'United States', 'Date': '12 Dec 1959', 'Winner': 'Bruce McLaren', 'Car': 'Cooper Climax', 'Laps': '42.0', 'Time': '2:12:35.700', 'WinnerCode': 'MCL', 'Year': '1959', 'Nationality': 'NZL'}
# {'Grand Prix': 'Argentina', 'Date': '07 Feb 1960', 'Winner': 'Bruce McLaren', 'Car': 'Cooper Climax', 'Laps': '80.0', 'Time': '2:17:49.500', 'WinnerCode': 'MCL', 'Year': '1960', 'Nationality': 'NZL'}
# {'Grand Prix': 'Monaco', 'Date': '03 Jun 1962', 'Winner': 'Bruce McLaren', 'Car': 'Cooper Climax', 'Laps': '100.0', 'Time': '2:46:29.700', 'WinnerCode': 'MCL', 'Year': '1962', 'Nationality': 'NZL'}
# {'Grand Prix': 'Belgium', 'Date': '09 Jun 1968', 'Winner': 'Bruce McLaren', 'Car': 'McLaren Ford', 'Laps': '28.0', 'Time': '1:40:02.100', 'WinnerCode': 'MCL', 'Year': '1968', 'Nationality': 'NZL'}
# {'Grand Prix': 'Brazil', 'Date': '26 Jan 1975', 'Winner': 'Carlos Pace', 'Car': 'Brabham Ford', 'Laps': '40.0', 'Time': '1:44:41.170', 'WinnerCode': 'PAC', 'Year': '1975', 'Nationality': 'BRA'}
# {'Grand Prix': 'South Africa', 'Date': '30 Mar 1974', 'Winner': 'Carlos Reutemann', 'Car': 'Brabham Ford', 'Laps': '78.0', 'Time': '1:42:40.960', 'WinnerCode': 'REU', 'Year': '1974', 'Nationality': 'ARG'}
# {'Grand Prix': 'Austria', 'Date': '18 Aug 1974', 'Winner': 'Carlos Reutemann', 'Car': 'Brabham Ford', 'Laps': '54.0', 'Time': '1:28:44.720', 'WinnerCode': 'REU', 'Year': '1974', 'Nationality': 'ARG'}
# {'Grand Prix': 'United States', 'Date': '06 Oct 1974', 'Winner': 'Carlos Reutemann', 'Car': 'Brabham Ford', 'Laps': '59.0', 'Time': '1:40:21.439', 'WinnerCode': 'REU', 'Year': '1974', 'Nationality': 'ARG'}
# {'Grand Prix': 'Germany', 'Date': '03 Aug 1975', 'Winner': 'Carlos Reutemann', 'Car': 'Brabham Ford', 'Laps': '14.0', 'Time': '1:41:14.100', 'WinnerCode': 'REU', 'Year': '1975', 'Nationality': 'ARG'}
# {'Grand Prix': 'Brazil', 'Date': '23 Jan 1977', 'Winner': 'Carlos Reutemann', 'Car': 'Ferrari', 'Laps': '40.0', 'Time': '1:45:07.720', 'WinnerCode': 'REU', 'Year': '1977', 'Nationality': 'ARG'}
# {'Grand Prix': 'Brazil', 'Date': '29 Jan 1978', 'Winner': 'Carlos Reutemann', 'Car': 'Ferrari', 'Laps': '63.0', 'Time': '1:49:59.860', 'WinnerCode': 'REU', 'Year': '1978', 'Nationality': 'ARG'}
# {'Grand Prix': 'USA West', 'Date': '02 Apr 1978', 'Winner': 'Carlos Reutemann', 'Car': 'Ferrari', 'Laps': '80.0', 'Time': '1:52:01.301', 'WinnerCode': 'REU', 'Year': '1978', 'Nationality': 'ARG'}
# {'Grand Prix': 'Great Britain', 'Date': '16 Jul 1978', 'Winner': 'Carlos Reutemann', 'Car': 'Ferrari', 'Laps': '76.0', 'Time': '1:42:12.390', 'WinnerCode': 'REU', 'Year': '1978', 'Nationality': 'ARG'}
# {'Grand Prix': 'USA East', 'Date': '01 Oct 1978', 'Winner': 'Carlos Reutemann', 'Car': 'Ferrari', 'Laps': '59.0', 'Time': '1:40:48.800', 'WinnerCode': 'REU', 'Year': '1978', 'Nationality': 'ARG'}
# {'Grand Prix': 'Monaco', 'Date': '18 May 1980', 'Winner': 'Carlos Reutemann', 'Car': 'Williams Ford', 'Laps': '76.0', 'Time': '1:55:34.365', 'WinnerCode': 'REU', 'Year': '1980', 'Nationality': 'ARG'}
# {'Grand Prix': 'Brazil', 'Date': '29 Mar 1981', 'Winner': 'Carlos Reutemann', 'Car': 'Williams Ford', 'Laps': '62.0', 'Time': '2:00:23.660', 'WinnerCode': 'REU', 'Year': '1981', 'Nationality': 'ARG'}
# {'Grand Prix': 'Belgium', 'Date': '17 May 1981', 'Winner': 'Carlos Reutemann', 'Car': 'Williams Ford', 'Laps': '54.0', 'Time': '1:16:31.610', 'WinnerCode': 'REU', 'Year': '1981', 'Nationality': 'ARG'}
# {'Grand Prix': 'Great Britain', 'Date': '03 Jul 2022', 'Winner': 'Carlos Sainz', 'Car': 'Ferrari', 'Laps': '52.0', 'Time': '2:17:50.311', 'WinnerCode': 'SAI', 'Year': '2022', 'Nationality': 'ESP'}
# {'Grand Prix': 'Belgium', 'Date': '01 Sep 2019', 'Winner': 'Charles Leclerc', 'Car': 'Ferrari', 'Laps': '44.0', 'Time': '1:23:45.710', 'WinnerCode': 'LEC', 'Year': '2019', 'Nationality': 'MON'}
# {'Grand Prix': 'Italy', 'Date': '08 Sep 2019', 'Winner': 'Charles Leclerc', 'Car': 'Ferrari', 'Laps': '53.0', 'Time': '1:15:26.665', 'WinnerCode': 'LEC', 'Year': '2019', 'Nationality': 'MON'}
# {'Grand Prix': 'Bahrain', 'Date': '20 Mar 2022', 'Winner': 'Charles Leclerc', 'Car': 'Ferrari', 'Laps': '57.0', 'Time': '1:37:33.584', 'WinnerCode': 'LEC', 'Year': '2022', 'Nationality': 'MON'}
# {'Grand Prix': 'Australia', 'Date': '10 Apr 2022', 'Winner': 'Charles Leclerc', 'Car': 'Ferrari', 'Laps': '58.0', 'Time': '1:27:46.548', 'WinnerCode': 'LEC', 'Year': '2022', 'Nationality': 'MON'}
# {'Grand Prix': 'Austria', 'Date': '10 Jul 2022', 'Winner': 'Charles Leclerc', 'Car': 'Ferrari', 'Laps': '71.0', 'Time': '1:24:24.312', 'WinnerCode': 'LEC', 'Year': '2022', 'Nationality': 'MON'}
# {'Grand Prix': 'Italy', 'Date': '06 Sep 1970', 'Winner': 'Clay Regazzoni', 'Car': 'Ferrari', 'Laps': '68.0', 'Time': '1:39:06.880', 'WinnerCode': 'REG', 'Year': '1970', 'Nationality': 'SUI'}
# {'Grand Prix': 'Germany', 'Date': '04 Aug 1974', 'Winner': 'Clay Regazzoni', 'Car': 'Ferrari', 'Laps': '14.0', 'Time': '1:41:35.000', 'WinnerCode': 'REG', 'Year': '1974', 'Nationality': 'SUI'}
# {'Grand Prix': 'Italy', 'Date': '07 Sep 1975', 'Winner': 'Clay Regazzoni', 'Car': 'Ferrari', 'Laps': '52.0', 'Time': '1:22:42.600', 'WinnerCode': 'REG', 'Year': '1975', 'Nationality': 'SUI'}
# {'Grand Prix': 'USA West', 'Date': '28 Mar 1976', 'Winner': 'Clay Regazzoni', 'Car': 'Ferrari', 'Laps': '80.0', 'Time': '1:53:18.471', 'WinnerCode': 'REG', 'Year': '1976', 'Nationality': 'SUI'}
# {'Grand Prix': 'Great Britain', 'Date': '14 Jul 1979', 'Winner': 'Clay Regazzoni', 'Car': 'Williams Ford', 'Laps': '68.0', 'Time': '1:26:11.170', 'WinnerCode': 'REG', 'Year': '1979', 'Nationality': 'SUI'}
# {'Grand Prix': 'Hungary', 'Date': '15 Aug 1993', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '77.0', 'Time': '1:47:39.098', 'WinnerCode': 'HIL', 'Year': '1993', 'Nationality': 'GBR'}
# {'Grand Prix': 'Belgium', 'Date': '29 Aug 1993', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '44.0', 'Time': '1:24:32.124', 'WinnerCode': 'HIL', 'Year': '1993', 'Nationality': 'GBR'}
# {'Grand Prix': 'Italy', 'Date': '12 Sep 1993', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '53.0', 'Time': '1:17:07.509', 'WinnerCode': 'HIL', 'Year': '1993', 'Nationality': 'GBR'}
# {'Grand Prix': 'Spain', 'Date': '29 May 1994', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '65.0', 'Time': '1:36:14.374', 'WinnerCode': 'HIL', 'Year': '1994', 'Nationality': 'GBR'}
# {'Grand Prix': 'Great Britain', 'Date': '10 Jul 1994', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '60.0', 'Time': '1:30:03.640', 'WinnerCode': 'HIL', 'Year': '1994', 'Nationality': 'GBR'}
# {'Grand Prix': 'Belgium', 'Date': '28 Aug 1994', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '44.0', 'Time': '1:28:47.170', 'WinnerCode': 'HIL', 'Year': '1994', 'Nationality': 'GBR'}
# {'Grand Prix': 'Italy', 'Date': '11 Sep 1994', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '53.0', 'Time': '1:18:02.754', 'WinnerCode': 'HIL', 'Year': '1994', 'Nationality': 'GBR'}
# {'Grand Prix': 'Portugal', 'Date': '25 Sep 1994', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '71.0', 'Time': '1:41:10.165', 'WinnerCode': 'HIL', 'Year': '1994', 'Nationality': 'GBR'}
# {'Grand Prix': 'Japan', 'Date': '06 Nov 1994', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '50.0', 'Time': '1:55:53.532', 'WinnerCode': 'HIL', 'Year': '1994', 'Nationality': 'GBR'}
# {'Grand Prix': 'Argentina', 'Date': '09 Apr 1995', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '71.0', 'Time': '1:51:39.531', 'WinnerCode': 'HIL', 'Year': '1995', 'Nationality': 'GBR'}
# {'Grand Prix': 'San Marino', 'Date': '30 Apr 1995', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '63.0', 'Time': '1:41:42.552', 'WinnerCode': 'HIL', 'Year': '1995', 'Nationality': 'GBR'}
# {'Grand Prix': 'Hungary', 'Date': '13 Aug 1995', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '77.0', 'Time': '1:46:25.721', 'WinnerCode': 'HIL', 'Year': '1995', 'Nationality': 'GBR'}
# {'Grand Prix': 'Australia', 'Date': '12 Nov 1995', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '81.0', 'Time': '1:49:15.946', 'WinnerCode': 'HIL', 'Year': '1995', 'Nationality': 'GBR'}
# {'Grand Prix': 'Australia', 'Date': '10 Mar 1996', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '58.0', 'Time': '1:32:50.491', 'WinnerCode': 'HIL', 'Year': '1996', 'Nationality': 'GBR'}
# {'Grand Prix': 'Brazil', 'Date': '31 Mar 1996', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '71.0', 'Time': '1:49:52.976', 'WinnerCode': 'HIL', 'Year': '1996', 'Nationality': 'GBR'}
# {'Grand Prix': 'Argentina', 'Date': '07 Apr 1996', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '72.0', 'Time': '1:54:55.322', 'WinnerCode': 'HIL', 'Year': '1996', 'Nationality': 'GBR'}
# {'Grand Prix': 'San Marino', 'Date': '05 May 1996', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '63.0', 'Time': '1:35:26.156', 'WinnerCode': 'HIL', 'Year': '1996', 'Nationality': 'GBR'}
# {'Grand Prix': 'Canada', 'Date': '16 Jun 1996', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '69.0', 'Time': '1:36:03.465', 'WinnerCode': 'HIL', 'Year': '1996', 'Nationality': 'GBR'}
# {'Grand Prix': 'France', 'Date': '30 Jun 1996', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '72.0', 'Time': '1:36:28.795', 'WinnerCode': 'HIL', 'Year': '1996', 'Nationality': 'GBR'}
# {'Grand Prix': 'Germany', 'Date': '28 Jul 1996', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '45.0', 'Time': '1:21:43.417', 'WinnerCode': 'HIL', 'Year': '1996', 'Nationality': 'GBR'}
# {'Grand Prix': 'Japan', 'Date': '13 Oct 1996', 'Winner': 'Damon Hill', 'Car': 'Williams Renault', 'Laps': '52.0', 'Time': '1:32:33.791', 'WinnerCode': 'HIL', 'Year': '1996', 'Nationality': 'GBR'}
# {'Grand Prix': 'Belgium', 'Date': '30 Aug 1998', 'Winner': 'Damon Hill', 'Car': 'Jordan Mugen Honda', 'Laps': '44.0', 'Time': '1:43:47.407', 'WinnerCode': 'HIL', 'Year': '1998', 'Nationality': 'GBR'}
# {'Grand Prix': 'France', 'Date': '08 Jul 1962', 'Winner': 'Dan Gurney', 'Car': 'Porsche', 'Laps': '54.0', 'Time': '2:07:35.500', 'WinnerCode': 'GUR', 'Year': '1962', 'Nationality': 'USA'}
# {'Grand Prix': 'France', 'Date': '28 Jun 1964', 'Winner': 'Dan Gurney', 'Car': 'Brabham Climax', 'Laps': '57.0', 'Time': '2:07:49.100', 'WinnerCode': 'GUR', 'Year': '1964', 'Nationality': 'USA'}
# {'Grand Prix': 'Mexico', 'Date': '25 Oct 1964', 'Winner': 'Dan Gurney', 'Car': 'Brabham Climax', 'Laps': '65.0', 'Time': '2:09:50.320', 'WinnerCode': 'GUR', 'Year': '1964', 'Nationality': 'USA'}
# {'Grand Prix': 'Belgium', 'Date': '18 Jun 1967', 'Winner': 'Dan Gurney', 'Car': 'Eagle Weslake', 'Laps': '28.0', 'Time': '1:40:49.400', 'WinnerCode': 'GUR', 'Year': '1967', 'Nationality': 'USA'}
# {'Grand Prix': 'Canada', 'Date': '08 Jun 2014', 'Winner': 'Daniel Ricciardo', 'Car': 'Red Bull Racing Renault', 'Laps': '70.0', 'Time': '1:39:12.830', 'WinnerCode': 'RIC', 'Year': '2014', 'Nationality': 'AUS'}
# {'Grand Prix': 'Hungary', 'Date': '27 Jul 2014', 'Winner': 'Daniel Ricciardo', 'Car': 'Red Bull Racing Renault', 'Laps': '70.0', 'Time': '1:53:05.058', 'WinnerCode': 'RIC', 'Year': '2014', 'Nationality': 'AUS'}
# {'Grand Prix': 'Belgium', 'Date': '24 Aug 2014', 'Winner': 'Daniel Ricciardo', 'Car': 'Red Bull Racing Renault', 'Laps': '44.0', 'Time': '1:24:36.556', 'WinnerCode': 'RIC', 'Year': '2014', 'Nationality': 'AUS'}
# {'Grand Prix': 'Malaysia', 'Date': '02 Oct 2016', 'Winner': 'Daniel Ricciardo', 'Car': 'Red Bull Racing TAG Heuer', 'Laps': '56.0', 'Time': '1:37:12.776', 'WinnerCode': 'RIC', 'Year': '2016', 'Nationality': 'AUS'}
# {'Grand Prix': 'Azerbaijan', 'Date': '25 Jun 2017', 'Winner': 'Daniel Ricciardo', 'Car': 'Red Bull Racing TAG Heuer', 'Laps': '51.0', 'Time': '2:03:55.573', 'WinnerCode': 'RIC', 'Year': '2017', 'Nationality': 'AUS'}
# {'Grand Prix': 'China', 'Date': '15 Apr 2018', 'Winner': 'Daniel Ricciardo', 'Car': 'Red Bull Racing TAG Heuer', 'Laps': '56.0', 'Time': '1:35:36.380', 'WinnerCode': 'RIC', 'Year': '2018', 'Nationality': 'AUS'}
# {'Grand Prix': 'Monaco', 'Date': '27 May 2018', 'Winner': 'Daniel Ricciardo', 'Car': 'Red Bull Racing TAG Heuer', 'Laps': '78.0', 'Time': '1:42:54.807', 'WinnerCode': 'RIC', 'Year': '2018', 'Nationality': 'AUS'}
# {'Grand Prix': 'Italy', 'Date': '12 Sep 2021', 'Winner': 'Daniel Ricciardo', 'Car': 'McLaren Mercedes', 'Laps': '53.0', 'Time': '1:21:54.365', 'WinnerCode': 'RIC', 'Year': '2021', 'Nationality': 'AUS'}
# {'Grand Prix': 'Portugal', 'Date': '24 Sep 1995', 'Winner': 'David Coulthard', 'Car': 'Williams Renault', 'Laps': '71.0', 'Time': '1:41:52.145', 'WinnerCode': 'COU', 'Year': '1995', 'Nationality': 'GBR'}
# {'Grand Prix': 'Australia', 'Date': '09 Mar 1997', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '58.0', 'Time': '1:30:28.718', 'WinnerCode': 'COU', 'Year': '1997', 'Nationality': 'GBR'}
# {'Grand Prix': 'Italy', 'Date': '07 Sep 1997', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '53.0', 'Time': '1:17:04.609', 'WinnerCode': 'COU', 'Year': '1997', 'Nationality': 'GBR'}
# {'Grand Prix': 'San Marino', 'Date': '26 Apr 1998', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '62.0', 'Time': '1:34:24.593', 'WinnerCode': 'COU', 'Year': '1998', 'Nationality': 'GBR'}
# {'Grand Prix': 'Great Britain', 'Date': '11 Jul 1999', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '60.0', 'Time': '1:32:30.144', 'WinnerCode': 'COU', 'Year': '1999', 'Nationality': 'GBR'}
# {'Grand Prix': 'Belgium', 'Date': '29 Aug 1999', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '44.0', 'Time': '1:25:43.057', 'WinnerCode': 'COU', 'Year': '1999', 'Nationality': 'GBR'}
# {'Grand Prix': 'Great Britain', 'Date': '23 Apr 2000', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '60.0', 'Time': '1:28:50.108', 'WinnerCode': 'COU', 'Year': '2000', 'Nationality': 'GBR'}
# {'Grand Prix': 'Monaco', 'Date': '04 Jun 2000', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '78.0', 'Time': '1:49:28.213', 'WinnerCode': 'COU', 'Year': '2000', 'Nationality': 'GBR'}
# {'Grand Prix': 'France', 'Date': '02 Jul 2000', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '72.0', 'Time': '1:38:05.538', 'WinnerCode': 'COU', 'Year': '2000', 'Nationality': 'GBR'}
# {'Grand Prix': 'Brazil', 'Date': '01 Apr 2001', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '71.0', 'Time': '1:39:00.834', 'WinnerCode': 'COU', 'Year': '2001', 'Nationality': 'GBR'}
# {'Grand Prix': 'Austria', 'Date': '13 May 2001', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '71.0', 'Time': '1:27:45.927', 'WinnerCode': 'COU', 'Year': '2001', 'Nationality': 'GBR'}
# {'Grand Prix': 'Monaco', 'Date': '26 May 2002', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '78.0', 'Time': '1:45:39.055', 'WinnerCode': 'COU', 'Year': '2002', 'Nationality': 'GBR'}
# {'Grand Prix': 'Australia', 'Date': '09 Mar 2003', 'Winner': 'David Coulthard', 'Car': 'McLaren Mercedes', 'Laps': '58.0', 'Time': '1:34:42.124', 'WinnerCode': 'COU', 'Year': '2003', 'Nationality': 'GBR'}
# {'Grand Prix': 'Monaco', 'Date': '07 May 1967', 'Winner': 'Denny Hulme', 'Car': 'Brabham Repco', 'Laps': '100.0', 'Time': '2:34:34.300', 'WinnerCode': 'HUL', 'Year': '1967', 'Nationality': 'NZL'}
# {'Grand Prix': 'Germany', 'Date': '06 Aug 1967', 'Winner': 'Denny Hulme', 'Car': 'Brabham Repco', 'Laps': '15.0', 'Time': '2:05:55.700', 'WinnerCode': 'HUL', 'Year': '1967', 'Nationality': 'NZL'}
# {'Grand Prix': 'Italy', 'Date': '08 Sep 1968', 'Winner': 'Denny Hulme', 'Car': 'McLaren Ford', 'Laps': '68.0', 'Time': '1:40:14.800', 'WinnerCode': 'HUL', 'Year': '1968', 'Nationality': 'NZL'}
# {'Grand Prix': 'Canada', 'Date': '22 Sep 1968', 'Winner': 'Denny Hulme', 'Car': 'McLaren Ford', 'Laps': '90.0', 'Time': '2:27:11.200', 'WinnerCode': 'HUL', 'Year': '1968', 'Nationality': 'NZL'}
# {'Grand Prix': 'Mexico', 'Date': '19 Oct 1969', 'Winner': 'Denny Hulme', 'Car': 'McLaren Ford', 'Laps': '65.0', 'Time': '1:54:08.800', 'WinnerCode': 'HUL', 'Year': '1969', 'Nationality': 'NZL'}
# {'Grand Prix': 'South Africa', 'Date': '04 Mar 1972', 'Winner': 'Denny Hulme', 'Car': 'McLaren Ford', 'Laps': '79.0', 'Time': '1:45:49.100', 'WinnerCode': 'HUL', 'Year': '1972', 'Nationality': 'NZL'}
# {'Grand Prix': 'Sweden', 'Date': '17 Jun 1973', 'Winner': 'Denny Hulme', 'Car': 'McLaren Ford', 'Laps': '80.0', 'Time': '1:56:46.049', 'WinnerCode': 'HUL', 'Year': '1973', 'Nationality': 'NZL'}
# {'Grand Prix': 'Argentina', 'Date': '13 Jan 1974', 'Winner': 'Denny Hulme', 'Car': 'McLaren Ford', 'Laps': '53.0', 'Time': '1:41:02.010', 'WinnerCode': 'HUL', 'Year': '1974', 'Nationality': 'NZL'}
# {'Grand Prix': 'Belgium', 'Date': '04 May 1980', 'Winner': 'Didier Pironi', 'Car': 'Ligier Ford', 'Laps': '72.0', 'Time': '1:38:46.510', 'WinnerCode': 'PIR', 'Year': '1980', 'Nationality': 'FRA'}
# {'Grand Prix': 'San Marino', 'Date': '25 Apr 1982', 'Winner': 'Didier Pironi', 'Car': 'Ferrari', 'Laps': '60.0', 'Time': '1:36:38.887', 'WinnerCode': 'PIR', 'Year': '1982', 'Nationality': 'FRA'}
# {'Grand Prix': 'Netherlands', 'Date': '03 Jul 1982', 'Winner': 'Didier Pironi', 'Car': 'Ferrari', 'Laps': '72.0', 'Time': '1:38:03.254', 'WinnerCode': 'PIR', 'Year': '1982', 'Nationality': 'FRA'}
# {'Grand Prix': 'Australia', 'Date': '07 Mar 1999', 'Winner': 'Eddie Irvine', 'Car': 'Ferrari', 'Laps': '57.0', 'Time': '1:35:01.659', 'WinnerCode': 'IRV', 'Year': '1999', 'Nationality': 'GBR'}
# {'Grand Prix': 'Austria', 'Date': '25 Jul 1999', 'Winner': 'Eddie Irvine', 'Car': 'Ferrari', 'Laps': '71.0', 'Time': '1:28:12.438', 'WinnerCode': 'IRV', 'Year': '1999', 'Nationality': 'GBR'}
# {'Grand Prix': 'Germany', 'Date': '01 Aug 1999', 'Winner': 'Eddie Irvine', 'Car': 'Ferrari', 'Laps': '45.0', 'Time': '1:21:58.594', 'WinnerCode': 'IRV', 'Year': '1999', 'Nationality': 'GBR'}
# {'Grand Prix': 'Malaysia', 'Date': '17 Oct 1999', 'Winner': 'Eddie Irvine', 'Car': 'Ferrari', 'Laps': '56.0', 'Time': '1:36:38.494', 'WinnerCode': 'IRV', 'Year': '1999', 'Nationality': 'GBR'}
# {'Grand Prix': 'Austria', 'Date': '15 Aug 1982', 'Winner': 'Elio de Angelis', 'Car': 'Lotus Ford', 'Laps': '53.0', 'Time': '1:25:02.212', 'WinnerCode': 'DEA', 'Year': '1982', 'Nationality': 'ITA'}
# {'Grand Prix': 'San Marino', 'Date': '05 May 1985', 'Winner': 'Elio de Angelis', 'Car': 'Lotus Renault', 'Laps': '60.0', 'Time': '1:34:35.955', 'WinnerCode': 'DEA', 'Year': '1985', 'Nationality': 'ITA'}
# {'Grand Prix': 'United States', 'Date': '04 Oct 1970', 'Winner': 'Emerson Fittipaldi', 'Car': 'Lotus Ford', 'Laps': '108.0', 'Time': '1:57:32.790', 'WinnerCode': 'FIT', 'Year': '1970', 'Nationality': 'BRA'}
# {'Grand Prix': 'Spain', 'Date': '01 May 1972', 'Winner': 'Emerson Fittipaldi', 'Car': 'Lotus Ford', 'Laps': '90.0', 'Time': '2:03:41.230', 'WinnerCode': 'FIT', 'Year': '1972', 'Nationality': 'BRA'}
# {'Grand Prix': 'Belgium', 'Date': '04 Jun 1972', 'Winner': 'Emerson Fittipaldi', 'Car': 'Lotus Ford', 'Laps': '85.0', 'Time': '1:44:06.700', 'WinnerCode': 'FIT', 'Year': '1972', 'Nationality': 'BRA'}
# {'Grand Prix': 'Great Britain', 'Date': '15 Jul 1972', 'Winner': 'Emerson Fittipaldi', 'Car': 'Lotus Ford', 'Laps': '76.0', 'Time': '1:47:50.200', 'WinnerCode': 'FIT', 'Year': '1972', 'Nationality': 'BRA'}
# {'Grand Prix': 'Austria', 'Date': '13 Aug 1972', 'Winner': 'Emerson Fittipaldi', 'Car': 'Lotus Ford', 'Laps': '54.0', 'Time': '1:29:16.660', 'WinnerCode': 'FIT', 'Year': '1972', 'Nationality': 'BRA'}
# {'Grand Prix': 'Italy', 'Date': '10 Sep 1972', 'Winner': 'Emerson Fittipaldi', 'Car': 'Lotus Ford', 'Laps': '55.0', 'Time': '1:29:58.400', 'WinnerCode': 'FIT', 'Year': '1972', 'Nationality': 'BRA'}
# {'Grand Prix': 'Argentina', 'Date': '28 Jan 1973', 'Winner': 'Emerson Fittipaldi', 'Car': 'Lotus Ford', 'Laps': '96.0', 'Time': '1:56:18.220', 'WinnerCode': 'FIT', 'Year': '1973', 'Nationality': 'BRA'}
# {'Grand Prix': 'Brazil', 'Date': '11 Feb 1973', 'Winner': 'Emerson Fittipaldi', 'Car': 'Lotus Ford', 'Laps': '40.0', 'Time': '1:43:55.600', 'WinnerCode': 'FIT', 'Year': '1973', 'Nationality': 'BRA'}
# {'Grand Prix': 'Spain', 'Date': '29 Apr 1973', 'Winner': 'Emerson Fittipaldi', 'Car': 'Lotus Ford', 'Laps': '75.0', 'Time': '1:48:18.700', 'WinnerCode': 'FIT', 'Year': '1973', 'Nationality': 'BRA'}
# {'Grand Prix': 'Brazil', 'Date': '27 Jan 1974', 'Winner': 'Emerson Fittipaldi', 'Car': 'McLaren Ford', 'Laps': '32.0', 'Time': '1:24:37.060', 'WinnerCode': 'FIT', 'Year': '1974', 'Nationality': 'BRA'}
# {'Grand Prix': 'Belgium', 'Date': '12 May 1974', 'Winner': 'Emerson Fittipaldi', 'Car': 'McLaren Ford', 'Laps': '85.0', 'Time': '1:44:20.570', 'WinnerCode': 'FIT', 'Year': '1974', 'Nationality': 'BRA'}
# {'Grand Prix': 'Canada', 'Date': '22 Sep 1974', 'Winner': 'Emerson Fittipaldi', 'Car': 'McLaren Ford', 'Laps': '80.0', 'Time': '1:40:26.136', 'WinnerCode': 'FIT', 'Year': '1974', 'Nationality': 'BRA'}
# {'Grand Prix': 'Argentina', 'Date': '12 Jan 1975', 'Winner': 'Emerson Fittipaldi', 'Car': 'McLaren Ford', 'Laps': '53.0', 'Time': '1:39:26.290', 'WinnerCode': 'FIT', 'Year': '1975', 'Nationality': 'BRA'}
# {'Grand Prix': 'Great Britain', 'Date': '19 Jul 1975', 'Winner': 'Emerson Fittipaldi', 'Car': 'McLaren Ford', 'Laps': '56.0', 'Time': '1:22:05.000', 'WinnerCode': 'FIT', 'Year': '1975', 'Nationality': 'BRA'}
# {'Grand Prix': 'Hungary', 'Date': '01 Aug 2021', 'Winner': 'Esteban Ocon', 'Car': 'Alpine Renault', 'Laps': '70.0', 'Time': '2:04:43.199', 'WinnerCode': 'OCO', 'Year': '2021', 'Nationality': 'FRA'}
# {'Grand Prix': 'Turkey', 'Date': '27 Aug 2006', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '58.0', 'Time': '1:28:51.082', 'WinnerCode': 'MAS', 'Year': '2006', 'Nationality': 'BRA'}
# {'Grand Prix': 'Brazil', 'Date': '22 Oct 2006', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '71.0', 'Time': '1:31:53.751', 'WinnerCode': 'MAS', 'Year': '2006', 'Nationality': 'BRA'}
# {'Grand Prix': 'Bahrain', 'Date': '15 Apr 2007', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '57.0', 'Time': '1:33:27.515', 'WinnerCode': 'MAS', 'Year': '2007', 'Nationality': 'BRA'}
# {'Grand Prix': 'Spain', 'Date': '13 May 2007', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '65.0', 'Time': '1:31:36.230', 'WinnerCode': 'MAS', 'Year': '2007', 'Nationality': 'BRA'}
# {'Grand Prix': 'Turkey', 'Date': '26 Aug 2007', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '58.0', 'Time': '1:26:42.161', 'WinnerCode': 'MAS', 'Year': '2007', 'Nationality': 'BRA'}
# {'Grand Prix': 'Bahrain', 'Date': '06 Apr 2008', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '57.0', 'Time': '1:31:06.970', 'WinnerCode': 'MAS', 'Year': '2008', 'Nationality': 'BRA'}
# {'Grand Prix': 'Turkey', 'Date': '11 May 2008', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '58.0', 'Time': '1:26:49.451', 'WinnerCode': 'MAS', 'Year': '2008', 'Nationality': 'BRA'}
# {'Grand Prix': 'France', 'Date': '22 Jun 2008', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '70.0', 'Time': '1:31:50.245', 'WinnerCode': 'MAS', 'Year': '2008', 'Nationality': 'BRA'}
# {'Grand Prix': 'Europe', 'Date': '24 Aug 2008', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '57.0', 'Time': '1:35:32.339', 'WinnerCode': 'MAS', 'Year': '2008', 'Nationality': 'BRA'}
# {'Grand Prix': 'Belgium', 'Date': '07 Sep 2008', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '44.0', 'Time': '1:22:59.394', 'WinnerCode': 'MAS', 'Year': '2008', 'Nationality': 'BRA'}
# {'Grand Prix': 'Brazil', 'Date': '02 Nov 2008', 'Winner': 'Felipe Massa', 'Car': 'Ferrari', 'Laps': '71.0', 'Time': '1:34:11.435', 'WinnerCode': 'MAS', 'Year': '2008', 'Nationality': 'BRA'}
# {'Grand Prix': 'Hungary', 'Date': '24 Aug 2003', 'Winner': 'Fernando Alonso', 'Car': 'Renault', 'Laps': '70.0', 'Time': '1:39:01.460', 'WinnerCode': 'ALO', 'Year': '2003', 'Nationality': 'ESP'}
# {'Grand Prix': 'Malaysia', 'Date': '20 Mar 2005', 'Winner': 'Fernando Alonso', 'Car': 'Renault', 'Laps': '56.0', 'Time': '1:31:33.736', 'WinnerCode': 'ALO', 'Year': '2005', 'Nationality': 'ESP'}
# {'Grand Prix': 'Bahrain', 'Date': '03 Apr 2005', 'Winner': 'Fernando Alonso', 'Car': 'Renault', 'Laps': '57.0', 'Time': '1:29:18.531', 'WinnerCode': 'ALO', 'Year': '2005', 'Nationality': 'ESP'}
# ...
# {'Grand Prix': 'Italy', 'Date': '11 Sep 2011', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '53.0', 'Time': '1:20:46.172', 'WinnerCode': 'VET', 'Year': '2011', 'Nationality': 'GER'}
# {'Grand Prix': 'Singapore', 'Date': '25 Sep 2011', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '61.0', 'Time': '1:59:06.757', 'WinnerCode': 'VET', 'Year': '2011', 'Nationality': 'GER'}
# {'Grand Prix': 'South Korea', 'Date': '16 Oct 2011', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '55.0', 'Time': '1:38:01.994', 'WinnerCode': 'VET', 'Year': '2011', 'Nationality': 'GER'}
# {'Grand Prix': 'India', 'Date': '30 Oct 2011', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '60.0', 'Time': '1:30:35.002', 'WinnerCode': 'VET', 'Year': '2011', 'Nationality': 'GER'}
# {'Grand Prix': 'Bahrain', 'Date': '22 Apr 2012', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '57.0', 'Time': '1:35:10.990', 'WinnerCode': 'VET', 'Year': '2012', 'Nationality': 'GER'}
# {'Grand Prix': 'Singapore', 'Date': '23 Sep 2012', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '59.0', 'Time': '2:00:26.144', 'WinnerCode': 'VET', 'Year': '2012', 'Nationality': 'GER'}
# {'Grand Prix': 'Japan', 'Date': '07 Oct 2012', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '53.0', 'Time': '1:28:56.242', 'WinnerCode': 'VET', 'Year': '2012', 'Nationality': 'GER'}
# {'Grand Prix': 'South Korea', 'Date': '14 Oct 2012', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '55.0', 'Time': '1:36:28.651', 'WinnerCode': 'VET', 'Year': '2012', 'Nationality': 'GER'}
# {'Grand Prix': 'India', 'Date': '28 Oct 2012', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '60.0', 'Time': '1:31:10.744', 'WinnerCode': 'VET', 'Year': '2012', 'Nationality': 'GER'}
# {'Grand Prix': 'Malaysia', 'Date': '24 Mar 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '56.0', 'Time': '1:38:56.681', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Bahrain', 'Date': '21 Apr 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '57.0', 'Time': '1:36:00.498', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Canada', 'Date': '09 Jun 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '70.0', 'Time': '1:32:09.143', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Germany', 'Date': '07 Jul 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '60.0', 'Time': '1:41:14.711', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Belgium', 'Date': '25 Aug 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '44.0', 'Time': '1:23:42.196', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Italy', 'Date': '08 Sep 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '53.0', 'Time': '1:18:33.352', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Singapore', 'Date': '22 Sep 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '61.0', 'Time': '1:59:13.132', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'South Korea', 'Date': '06 Oct 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '55.0', 'Time': '1:43:13.701', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Japan', 'Date': '13 Oct 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '53.0', 'Time': '1:26:49.301', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'India', 'Date': '27 Oct 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '60.0', 'Time': '1:31:12.187', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Abu Dhabi', 'Date': '03 Nov 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '55.0', 'Time': '1:38:06.106', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'United States', 'Date': '17 Nov 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '56.0', 'Time': '1:39:17.148', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Brazil', 'Date': '24 Nov 2013', 'Winner': 'Sebastian Vettel', 'Car': 'Red Bull Racing Renault', 'Laps': '71.0', 'Time': '1:32:36.300', 'WinnerCode': 'VET', 'Year': '2013', 'Nationality': 'GER'}
# {'Grand Prix': 'Malaysia', 'Date': '29 Mar 2015', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '56.0', 'Time': '1:41:05.793', 'WinnerCode': 'VET', 'Year': '2015', 'Nationality': 'GER'}
# {'Grand Prix': 'Hungary', 'Date': '26 Jul 2015', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '69.0', 'Time': '1:46:09.985', 'WinnerCode': 'VET', 'Year': '2015', 'Nationality': 'GER'}
# {'Grand Prix': 'Singapore', 'Date': '20 Sep 2015', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '61.0', 'Time': '2:01:22.118', 'WinnerCode': 'VET', 'Year': '2015', 'Nationality': 'GER'}
# {'Grand Prix': 'Australia', 'Date': '26 Mar 2017', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '57.0', 'Time': '1:24:11.672', 'WinnerCode': 'VET', 'Year': '2017', 'Nationality': 'GER'}
# {'Grand Prix': 'Bahrain', 'Date': '16 Apr 2017', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '57.0', 'Time': '1:33:53.374', 'WinnerCode': 'VET', 'Year': '2017', 'Nationality': 'GER'}
# {'Grand Prix': 'Monaco', 'Date': '28 May 2017', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '78.0', 'Time': '1:44:44.340', 'WinnerCode': 'VET', 'Year': '2017', 'Nationality': 'GER'}
# {'Grand Prix': 'Hungary', 'Date': '30 Jul 2017', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '70.0', 'Time': '1:39:46.713', 'WinnerCode': 'VET', 'Year': '2017', 'Nationality': 'GER'}
# {'Grand Prix': 'Brazil', 'Date': '12 Nov 2017', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '71.0', 'Time': '1:31:26.262', 'WinnerCode': 'VET', 'Year': '2017', 'Nationality': 'GER'}
# {'Grand Prix': 'Australia', 'Date': '25 Mar 2018', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '58.0', 'Time': '1:29:33.283', 'WinnerCode': 'VET', 'Year': '2018', 'Nationality': 'GER'}
# {'Grand Prix': 'Bahrain', 'Date': '08 Apr 2018', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '57.0', 'Time': '1:32:01.940', 'WinnerCode': 'VET', 'Year': '2018', 'Nationality': 'GER'}
# {'Grand Prix': 'Canada', 'Date': '10 Jun 2018', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '68.0', 'Time': '1:28:31.377', 'WinnerCode': 'VET', 'Year': '2018', 'Nationality': 'GER'}
# {'Grand Prix': 'Great Britain', 'Date': '08 Jul 2018', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '52.0', 'Time': '1:27:29.784', 'WinnerCode': 'VET', 'Year': '2018', 'Nationality': 'GER'}
# {'Grand Prix': 'Belgium', 'Date': '26 Aug 2018', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '44.0', 'Time': '1:23:34.476', 'WinnerCode': 'VET', 'Year': '2018', 'Nationality': 'GER'}
# {'Grand Prix': 'Singapore', 'Date': '22 Sep 2019', 'Winner': 'Sebastian Vettel', 'Car': 'Ferrari', 'Laps': '61.0', 'Time': '1:58:33.667', 'WinnerCode': 'VET', 'Year': '2019', 'Nationality': 'GER'}
# {'Grand Prix': 'Sakhir', 'Date': '06 Dec 2020', 'Winner': 'Sergio Perez', 'Car': 'Racing Point BWT Mercedes', 'Laps': '87.0', 'Time': '1:31:15.114', 'WinnerCode': 'PER', 'Year': '2020', 'Nationality': 'MEX'}
# {'Grand Prix': 'Azerbaijan', 'Date': '06 Jun 2021', 'Winner': 'Sergio Perez', 'Car': 'Red Bull Racing Honda', 'Laps': '51.0', 'Time': '2:13:36.410', 'WinnerCode': 'PER', 'Year': '2021', 'Nationality': 'MEX'}
# {'Grand Prix': 'Monaco', 'Date': '29 May 2022', 'Winner': 'Sergio Perez', 'Car': 'Red Bull Racing RBPT', 'Laps': '64.0', 'Time': '1:56:30.265', 'WinnerCode': 'PER', 'Year': '2022', 'Nationality': 'MEX'}
# {'Grand Prix': 'Singapore', 'Date': '02 Oct 2022', 'Winner': 'Sergio Perez', 'Car': 'Red Bull Racing RBPT', 'Laps': '59.0', 'Time': '2:02:20.238', 'WinnerCode': 'PER', 'Year': '2022', 'Nationality': 'MEX'}
# {'Grand Prix': 'Great Britain', 'Date': '16 Jul 1955', 'Winner': 'Stirling Moss', 'Car': 'Mercedes-Benz', 'Laps': '90.0', 'Time': '3:07:21.200', 'WinnerCode': 'MOS', 'Year': '1955', 'Nationality': 'GBR'}
# {'Grand Prix': 'Monaco', 'Date': '13 May 1956', 'Winner': 'Stirling Moss', 'Car': 'Maserati', 'Laps': '100.0', 'Time': '3:00:32.900', 'WinnerCode': 'MOS', 'Year': '1956', 'Nationality': 'GBR'}
# {'Grand Prix': 'Italy', 'Date': '02 Sep 1956', 'Winner': 'Stirling Moss', 'Car': 'Maserati', 'Laps': '50.0', 'Time': '2:23:41.300', 'WinnerCode': 'MOS', 'Year': '1956', 'Nationality': 'GBR'}
# {'Grand Prix': 'Great Britain', 'Date': '20 Jul 1957', 'Winner': 'Stirling Moss', 'Car': 'Vanwall', 'Laps': '90.0', 'Time': '3:06:37.800', 'WinnerCode': 'MOS', 'Year': '1957', 'Nationality': 'GBR'}
# {'Grand Prix': 'Pescara', 'Date': '18 Aug 1957', 'Winner': 'Stirling Moss', 'Car': 'Vanwall', 'Laps': '18.0', 'Time': '2:59:22.700', 'WinnerCode': 'MOS', 'Year': '1957', 'Nationality': 'GBR'}
# {'Grand Prix': 'Italy', 'Date': '08 Sep 1957', 'Winner': 'Stirling Moss', 'Car': 'Vanwall', 'Laps': '87.0', 'Time': '2:35:03.900', 'WinnerCode': 'MOS', 'Year': '1957', 'Nationality': 'GBR'}
# {'Grand Prix': 'Argentina', 'Date': '19 Jan 1958', 'Winner': 'Stirling Moss', 'Car': 'Cooper Climax', 'Laps': '80.0', 'Time': '2:19:33.700', 'WinnerCode': 'MOS', 'Year': '1958', 'Nationality': 'GBR'}
# {'Grand Prix': 'Netherlands', 'Date': '26 May 1958', 'Winner': 'Stirling Moss', 'Car': 'Vanwall', 'Laps': '75.0', 'Time': '2:04:49.200', 'WinnerCode': 'MOS', 'Year': '1958', 'Nationality': 'GBR'}
# {'Grand Prix': 'Portugal', 'Date': '24 Aug 1958', 'Winner': 'Stirling Moss', 'Car': 'Vanwall', 'Laps': '50.0', 'Time': '2:11:27.800', 'WinnerCode': 'MOS', 'Year': '1958', 'Nationality': 'GBR'}
# {'Grand Prix': 'Morocco', 'Date': '19 Oct 1958', 'Winner': 'Stirling Moss', 'Car': 'Vanwall', 'Laps': '53.0', 'Time': '2:09:15.100', 'WinnerCode': 'MOS', 'Year': '1958', 'Nationality': 'GBR'}
# {'Grand Prix': 'Portugal', 'Date': '23 Aug 1959', 'Winner': 'Stirling Moss', 'Car': 'Cooper Climax', 'Laps': '62.0', 'Time': '2:11:55.410', 'WinnerCode': 'MOS', 'Year': '1959', 'Nationality': 'GBR'}
# {'Grand Prix': 'Italy', 'Date': '13 Sep 1959', 'Winner': 'Stirling Moss', 'Car': 'Cooper Climax', 'Laps': '72.0', 'Time': '2:04:05.400', 'WinnerCode': 'MOS', 'Year': '1959', 'Nationality': 'GBR'}
# {'Grand Prix': 'Monaco', 'Date': '29 May 1960', 'Winner': 'Stirling Moss', 'Car': 'Lotus Climax', 'Laps': '100.0', 'Time': '2:53:45.500', 'WinnerCode': 'MOS', 'Year': '1960', 'Nationality': 'GBR'}
# {'Grand Prix': 'United States', 'Date': '20 Nov 1960', 'Winner': 'Stirling Moss', 'Car': 'Lotus Climax', 'Laps': '75.0', 'Time': '2:28:52.200', 'WinnerCode': 'MOS', 'Year': '1960', 'Nationality': 'GBR'}
# {'Grand Prix': 'Monaco', 'Date': '14 May 1961', 'Winner': 'Stirling Moss', 'Car': 'Lotus Climax', 'Laps': '100.0', 'Time': '2:45:50.100', 'WinnerCode': 'MOS', 'Year': '1961', 'Nationality': 'GBR'}
# {'Grand Prix': 'Germany', 'Date': '06 Aug 1961', 'Winner': 'Stirling Moss', 'Car': 'Lotus Climax', 'Laps': '15.0', 'Time': '2:18:12.400', 'WinnerCode': 'MOS', 'Year': '1961', 'Nationality': 'GBR'}
# {'Grand Prix': 'Canada', 'Date': '18 Jun 1989', 'Winner': 'Thierry Boutsen', 'Car': 'Williams Renault', 'Laps': '69.0', 'Time': '2:01:24.073', 'WinnerCode': 'BOU', 'Year': '1989', 'Nationality': 'BEL'}
# {'Grand Prix': 'Australia', 'Date': '05 Nov 1989', 'Winner': 'Thierry Boutsen', 'Car': 'Williams Renault', 'Laps': '70.0', 'Time': '2:00:17.421', 'WinnerCode': 'BOU', 'Year': '1989', 'Nationality': 'BEL'}
# {'Grand Prix': 'Hungary', 'Date': '12 Aug 1990', 'Winner': 'Thierry Boutsen', 'Car': 'Williams Renault', 'Laps': '77.0', 'Time': '1:49:30.597', 'WinnerCode': 'BOU', 'Year': '1990', 'Nationality': 'BEL'}
# {'Grand Prix': 'Great Britain', 'Date': '20 Jul 1957', 'Winner': 'Tony Brooks', 'Car': 'Vanwall', 'Laps': '', 'Time': '', 'WinnerCode': 'BRO', 'Year': '1957', 'Nationality': 'GBR'}
# {'Grand Prix': 'Belgium', 'Date': '15 Jun 1958', 'Winner': 'Tony Brooks', 'Car': 'Vanwall', 'Laps': '24.0', 'Time': '1:37:06.300', 'WinnerCode': 'BRO', 'Year': '1958', 'Nationality': 'GBR'}
# {'Grand Prix': 'Germany', 'Date': '03 Aug 1958', 'Winner': 'Tony Brooks', 'Car': 'Vanwall', 'Laps': '15.0', 'Time': '2:21:15.000', 'WinnerCode': 'BRO', 'Year': '1958', 'Nationality': 'GBR'}
# {'Grand Prix': 'Italy', 'Date': '07 Sep 1958', 'Winner': 'Tony Brooks', 'Car': 'Vanwall', 'Laps': '70.0', 'Time': '2:03:47.800', 'WinnerCode': 'BRO', 'Year': '1958', 'Nationality': 'GBR'}
# {'Grand Prix': 'France', 'Date': '05 Jul 1959', 'Winner': 'Tony Brooks', 'Car': 'Ferrari', 'Laps': '50.0', 'Time': '2:01:26.500', 'WinnerCode': 'BRO', 'Year': '1959', 'Nationality': 'GBR'}
# {'Grand Prix': 'Germany', 'Date': '02 Aug 1959', 'Winner': 'Tony Brooks', 'Car': 'Ferrari', 'Laps': '60.0', 'Time': '2:09:31.600', 'WinnerCode': 'BRO', 'Year': '1959', 'Nationality': 'GBR'}
# {'Grand Prix': 'Indianapolis 500', 'Date': '30 May 1952', 'Winner': 'Troy Ruttman', 'Car': 'Kuzma Offenhauser', 'Laps': '200.0', 'Time': '3:52:41.880', 'WinnerCode': 'RUT', 'Year': '1952', 'Nationality': 'USA'}
# {'Grand Prix': 'Russia', 'Date': '30 Apr 2017', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '52.0', 'Time': '1:28:08.743', 'WinnerCode': 'BOT', 'Year': '2017', 'Nationality': 'FIN'}
# {'Grand Prix': 'Austria', 'Date': '09 Jul 2017', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '71.0', 'Time': '1:21:48.523', 'WinnerCode': 'BOT', 'Year': '2017', 'Nationality': 'FIN'}
# {'Grand Prix': 'Abu Dhabi', 'Date': '26 Nov 2017', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '55.0', 'Time': '1:34:14.062', 'WinnerCode': 'BOT', 'Year': '2017', 'Nationality': 'FIN'}
# {'Grand Prix': 'Australia', 'Date': '17 Mar 2019', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '58.0', 'Time': '1:25:27.325', 'WinnerCode': 'BOT', 'Year': '2019', 'Nationality': 'FIN'}
# {'Grand Prix': 'Azerbaijan', 'Date': '28 Apr 2019', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '51.0', 'Time': '1:31:52.942', 'WinnerCode': 'BOT', 'Year': '2019', 'Nationality': 'FIN'}
# {'Grand Prix': 'Japan', 'Date': '13 Oct 2019', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '52.0', 'Time': '1:21:46.755', 'WinnerCode': 'BOT', 'Year': '2019', 'Nationality': 'FIN'}
# {'Grand Prix': 'United States', 'Date': '03 Nov 2019', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '56.0', 'Time': '1:33:55.653', 'WinnerCode': 'BOT', 'Year': '2019', 'Nationality': 'FIN'}
# {'Grand Prix': 'Austria', 'Date': '05 Jul 2020', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '71.0', 'Time': '1:30:55.739', 'WinnerCode': 'BOT', 'Year': '2020', 'Nationality': 'FIN'}
# {'Grand Prix': 'Russia', 'Date': '27 Sep 2020', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '53.0', 'Time': '1:34:00.364', 'WinnerCode': 'BOT', 'Year': '2020', 'Nationality': 'FIN'}
# {'Grand Prix': 'Turkey', 'Date': '10 Oct 2021', 'Winner': 'Valtteri Bottas', 'Car': 'Mercedes', 'Laps': '58.0', 'Time': '1:31:04.103', 'WinnerCode': 'BOT', 'Year': '2021', 'Nationality': 'FIN'}
# {'Grand Prix': 'Austria', 'Date': '17 Aug 1975', 'Winner': 'Vittorio Brambilla', 'Car': 'March Ford', 'Laps': '29.0', 'Time': '57:56.690', 'WinnerCode': 'BRA', 'Year': '1975', 'Nationality': 'ITA'}
# {'Grand Prix': 'Netherlands', 'Date': '22 May 1961', 'Winner': 'Wolfgang von Trips', 'Car': 'Ferrari', 'Laps': '75.0', 'Time': '2:01:52.100', 'WinnerCode': 'VON', 'Year': '1961', 'Nationality': 'GER'}
# {'Grand Prix': 'Great Britain', 'Date': '15 Jul 1961', 'Winner': 'Wolfgang von Trips', 'Car': 'Ferrari', 'Laps': '75.0', 'Time': '2:40:53.600', 'WinnerCode': 'VON', 'Year': '1961', 'Nationality': 'GER'}

# %% [markdown]
# **3. Escreva uma ou mais funções do paradigma funcional, cujo o objetivo desta tarefa é ler os dados do arquivo "driver_standings.csv" e listar os pilotos que foram campeões da Fórmula 1, em quais anos foram campeões, e quantas vezes foram campeões.**
#
# - **Para testar, é necessário usar a função auxiliar `mostra_dados` conforme apresentado abaixo.**
# ```python
# mostra_dados("quantidade_de_vezes_em_que_piloto_foi_campeao", "driver_standings.csv", quantidade_de_vezes_em_que_piloto_foi_campeao)
# ```
#
# - **Exemplo de saída esperada (não é obrigatório o uso de dicionário, pode ser apresentado de outras formas, usando listas ou tuplas):**
# ```bash
# |___    quantidade_de_vezes_em_que_piloto_foi_campeao   ___|
# ('Alain Prost', {'anos': [1985, 1986, 1989, 1993], 'quantidade': 4})
# ('Alan Jones', {'anos': [1980], 'quantidade': 1})
# ('Alberto Ascari', {'anos': [1952, 1953], 'quantidade': 2})
# ('Ayrton Senna', {'anos': [1988, 1990, 1991], 'quantidade': 3})
# ('Damon Hill', {'anos': [1996], 'quantidade': 1})
# ('Denny Hulme', {'anos': [1967], 'quantidade': 1})
# ('Emerson Fittipaldi', {'anos': [1972, 1974], 'quantidade': 2})
# ('Fernando Alonso', {'anos': [2005, 2006], 'quantidade': 2})
# ('Graham Hill', {'anos': [1962, 1968], 'quantidade': 2})
# ('Jack Brabham', {'anos': [1959, 1960, 1966], 'quantidade': 3})
# ('Jackie Stewart', {'anos': [1969, 1971, 1973], 'quantidade': 3})
# ('Jacques Villeneuve', {'anos': [1997], 'quantidade': 1})
# ('James Hunt', {'anos': [1976], 'quantidade': 1})
# ('Jenson Button', {'anos': [2009], 'quantidade': 1})
# ('Jim Clark', {'anos': [1963, 1965], 'quantidade': 2})
# ('Jochen Rindt', {'anos': [1970], 'quantidade': 1})
# ('Jody Scheckter', {'anos': [1979], 'quantidade': 1})
# ('John Surtees', {'anos': [1964], 'quantidade': 1})
# ('Juan Manuel Fangio', {'anos': [1951, 1954, 1955, 1956, 1957], 'quantidade': 5})
# ('Keke Rosberg', {'anos': [1982], 'quantidade': 1})
# ('Kimi Räikkönen', {'anos': [2007], 'quantidade': 1})
# ('Lewis Hamilton', {'anos': [2008, 2014, 2015, 2017, 2018, 2019, 2020], 'quantidade': 7})
# ('Mario Andretti', {'anos': [1978], 'quantidade': 1})
# ('Max Verstappen', {'anos': [2021, 2022], 'quantidade': 2})
# ('Michael Schumacher', {'anos': [1994, 1995, 2000, 2001, 2002, 2003, 2004], 'quantidade': 7})
# ('Mika Hakkinen', {'anos': [1998, 1999], 'quantidade': 2})
# ('Mike Hawthorn', {'anos': [1958], 'quantidade': 1})
# ('Nelson Piquet', {'anos': [1981, 1983, 1987], 'quantidade': 3})
# ('Nico Rosberg', {'anos': [2016], 'quantidade': 1})
# ('Nigel Mansell', {'anos': [1992], 'quantidade': 1})
# ('Niki Lauda', {'anos': [1975, 1977, 1984], 'quantidade': 3})
# ('Nino Farina', {'anos': [1950], 'quantidade': 1})
# ('Phil Hill', {'anos': [1961], 'quantidade': 1})
# ('Sebastian Vettel', {'anos': [2010, 2011, 2012, 2013], 'quantidade': 4})
# ```

# %%
def retorna_nome_piloto(lista_pilotos): #Função que retorna o primeiro elemento, da primeira tupla
        return lista_pilotos[0][0]

    
def organiza_dados(tupla_piloto,dicionarios): #Função que organiza os dados, e chama outras funções.
    if tupla_piloto == []:
        return []
    else:
        nome_piloto = retorna_nome_piloto(tupla_piloto)
        lista_filtrada_nome_piloto = list(filter(lambda x: x["Driver"] == nome_piloto and x["Pos"] == "1",dicionarios))
        return [(nome_piloto,dict(anos = list(map(lambda x: x["Year"],lista_filtrada_nome_piloto)),quantidade = len(lista_filtrada_nome_piloto)))] + organiza_dados(tupla_piloto[1:],dicionarios)

def quantidade_de_vezes_em_que_piloto_foi_campeao(iterador): #Função que transforma os dados recebidos como argumento (iterador) em dados manipuláveis.
     dados_drive_standings = list(iterador)
     pilotos_campeoes = filter(lambda x: x["Pos"] == "1",dados_drive_standings)
     tupla_piloto = sorted(set(map(lambda x: (x["Driver"],),pilotos_campeoes)))
     return organiza_dados(tupla_piloto,dados_drive_standings)
    
mostra_dados("Quantidade_de_vezes_em_que_piloto_foi_campeao","driver_standings.csv",quantidade_de_vezes_em_que_piloto_foi_campeao)
# Out:
# |___    Quantidade_de_vezes_em_que_piloto_foi_campeao   ___|
# ('Alain Prost', {'anos': ['1985', '1986', '1989', '1993'], 'quantidade': 4})
# ('Alan Jones', {'anos': ['1980'], 'quantidade': 1})
# ('Alberto Ascari', {'anos': ['1952', '1953'], 'quantidade': 2})
# ('Ayrton Senna', {'anos': ['1988', '1990', '1991'], 'quantidade': 3})
# ('Damon Hill', {'anos': ['1996'], 'quantidade': 1})
# ('Denny Hulme', {'anos': ['1967'], 'quantidade': 1})
# ('Emerson Fittipaldi', {'anos': ['1972', '1974'], 'quantidade': 2})
# ('Fernando Alonso', {'anos': ['2005', '2006'], 'quantidade': 2})
# ('Graham Hill', {'anos': ['1962', '1968'], 'quantidade': 2})
# ('Jack Brabham', {'anos': ['1959', '1960', '1966'], 'quantidade': 3})
# ('Jackie Stewart', {'anos': ['1969', '1971', '1973'], 'quantidade': 3})
# ('Jacques Villeneuve', {'anos': ['1997'], 'quantidade': 1})
# ('James Hunt', {'anos': ['1976'], 'quantidade': 1})
# ('Jenson Button', {'anos': ['2009'], 'quantidade': 1})
# ('Jim Clark', {'anos': ['1963', '1965'], 'quantidade': 2})
# ('Jochen Rindt', {'anos': ['1970'], 'quantidade': 1})
# ('Jody Scheckter', {'anos': ['1979'], 'quantidade': 1})
# ('John Surtees', {'anos': ['1964'], 'quantidade': 1})
# ('Juan Manuel Fangio', {'anos': ['1951', '1954', '1955', '1956', '1957'], 'quantidade': 5})
# ('Keke Rosberg', {'anos': ['1982'], 'quantidade': 1})
# ('Kimi Räikkönen', {'anos': ['2007'], 'quantidade': 1})
# ('Lewis Hamilton', {'anos': ['2008', '2014', '2015', '2017', '2018', '2019', '2020'], 'quantidade': 7})
# ('Mario Andretti', {'anos': ['1978'], 'quantidade': 1})
# ('Max Verstappen', {'anos': ['2021', '2022'], 'quantidade': 2})
# ('Michael Schumacher', {'anos': ['1994', '1995', '2000', '2001', '2002', '2003', '2004'], 'quantidade': 7})
# ('Mika Hakkinen', {'anos': ['1998', '1999'], 'quantidade': 2})
# ('Mike Hawthorn', {'anos': ['1958'], 'quantidade': 1})
# ('Nelson Piquet', {'anos': ['1981', '1983', '1987'], 'quantidade': 3})
# ('Nico Rosberg', {'anos': ['2016'], 'quantidade': 1})
# ('Nigel Mansell', {'anos': ['1992'], 'quantidade': 1})
# ('Niki Lauda', {'anos': ['1975', '1977', '1984'], 'quantidade': 3})
# ('Nino Farina', {'anos': ['1950'], 'quantidade': 1})
# ('Phil Hill', {'anos': ['1961'], 'quantidade': 1})
# ('Sebastian Vettel', {'anos': ['2010', '2011', '2012', '2013'], 'quantidade': 4})

# %% [markdown]
# ## Parte 2: Listas encadeadas

# %% [markdown]
# ### Funções Auxiliares

# %%
def head(L):
    return L[0]

def tail(L):
    return L[1]

# %% [markdown]
# ### Lista para testes:

# %%
LL = (255, (77, (19, (20, (80, (15, (150, None)))))))

# %% [markdown]
# **4. Implemente uma função principal `bubbleSort`, de forma que ela receba uma lista encadeada `LL`, faça o ordenamento, e retorne uma nova lista encadeada (`LL`). Poderão ser criadas funções auxiliares que respeitam o principio do paradigma funcional.**
#
# - <font color="green">
# <b>
# Lembrando: O algoritmo de ordenação Bubble Sort percorre repetidamente a lista, compara elementos adjacentes e os troca se estiverem na ordem errada. O processo é repetido até que a lista esteja ordenada. Para uma visualização melhor do funcionamento do algoritmo, observe o gif abaixo:
# </font>
#
# ![Bubble Sort](https://upload.wikimedia.org/wikipedia/commons/c/c8/Bubble-sort-example-300px.gif)
#
# **Para mais detalhes sobre o bubble sort acesse: https://visualgo.net/en/sorting**
#
# **Resultado Esperado:**
# Sorted-LL: (15, (19, (20, (77, (80, (150, (255, None)))))))

# %%
def ordena_lista(lista_encadeada): #Função que ordena a lista encadeada, caso esteja desordenada.
    dados = lista_encadeada
    if tail(dados) != None:
        if head(dados) > head(tail(dados)):
            maior = head(dados)
            menor = head(tail(dados))
            cauda = tail(tail(dados))
            return (menor,ordena_lista((maior,cauda)))
        else:
            return (head(dados),ordena_lista(tail(dados)))
    else:
        return dados
    
def retorna_ultimo(LL): #Função que retorna o último elemento de uma lista encadeada.
    if tail(LL) == None:
        return head(LL)
    else:
        return retorna_ultimo(tail(LL))

def retorna_maior(dados): #Função recursiva que retorna o maior número de uma lista encadeada.
    if tail(dados) == None:  
        return head(dados)
    maior = retorna_maior(tail(dados))
    if head(dados) > maior:
        return head(dados)
    else:
        return maior
    
def retorna_menor(dados): #Função recursiva que retorna o menor número de uma lista encadeada.
    if tail(dados) == None:
        return head(dados)
    menor = retorna_menor(tail(dados))
    if head(dados) < menor:
        return head(dados)
    else:
        return menor

def bubble_sort(LL,maior,menor): #Função principal que chama as outras funções.
    data = ordena_lista(LL)
    if head(data) == menor and retorna_ultimo(LL) == maior:
        return data
    else:
        return bubble_sort(data,maior,menor)  
    
LL_ordenada = bubble_sort(LL,retorna_maior(LL),retorna_menor(LL))
print(LL_ordenada)
# Out:
# (15, (19, (20, (77, (80, (150, (255, None)))))))

# %% [markdown]
# ## Parte 3: Funções de alta ordem com listas encadeadas

# %% [markdown]
# ### Funções Auxiliares

# %%
def head(L):
    return L[0]

def tail(L):
    return L[1]

# %% [markdown]
# ### Lista para testes:

# %%
LLs = ("Michael Schumacher", ("Nelson Piquet", ("Emerson Fittipaldi", ("Alain Prost", ("Ayrton Senna", ("Max Verstappen", ("Charles Leclerc", None)))))))

# %% [markdown]
# **5. Implemente as seguintes funções de alta ordem e puras para trabalhar com listas encadeadas.**
#
# - a) `mapLL` deve receber uma função `F` que é aplicada sob cada elemento de uma lista encadeada `LL` que é passada como parâmetro (`mapLL(LL,F)`), retornando uma nova lista encadeada (`LL'`) modificada pela função `L`. Desenvolva também as seguintes funções que serão passadas para `mapLL(LL,F)`:
#     + Função que transformar em minúsculas todas as letras de cada nome.
#     + Funco que inverter a ordem dos caracteres de cada nome.
# - b) `filterLL` deve recebe uma lista encadeada `LL` e uma função `F`, de modo que produza uma nova lista com cada elemento de `LL` que seja verdade para `F`.  Desenvolva também as seguintes funções que serão passadas para `filterLL(LL,F):
#     + Função que retorna verdadeiro quando o nome possui a letra `p`.
#     + Função que retorna verdadeiro quando o nome possui até ou igual a 12 caracteres.
#
#   _OBS: podem ser criadas funções `lambda` e passar diretamente em `mapLL` e `filterLL`._
#
# **Resultado Esperado:**
# ```bash
# mapLL: ('MICHAEL SCHUMACHER', ('NELSON PIQUET', ('EMERSON FITTIPALDI', ('ALAIN PROST', ('AYRTON SENNA', ('MAX VERSTAPPEN', ('CHARLES LECLERC', None)))))))
# mapLL: ('rehcamuhcS leahciM', ('teuqiP nosleN', ('idlapittiF nosremE', ('tsorP nialA', ('anneS notryA', ('neppatsreV xaM', ('crelceL selrahC', None)))))))
# filterLL: ('Nelson Piquet', ('Emerson Fittipaldi', ('Alain Prost', ('Max Verstappen', None))))
# filterLL: ('Alain Prost', ('Ayrton Senna', None))
# ```

# %%
def mapLL(lista_encadeada,func): #Função mapLL
    if lista_encadeada == None:
        return None
    else:
        return (func(head(lista_encadeada)),mapLL(tail(lista_encadeada),func))

def filterLL(lista_encadeada,func): #Função filterLL
    if lista_encadeada == None:
        return None
    elif func(head(lista_encadeada)) == True:
        return (head(lista_encadeada),filterLL(tail(lista_encadeada),func))
    else:
        return (filterLL(tail(lista_encadeada),func))
    
print(mapLL(LLs,lambda x: x.lower()))
print(mapLL(LLs,lambda x: x[::-1]))
print(filterLL(LLs,lambda x:  "p" in x.lower()))
print(filterLL(LLs,lambda x: len(x) <= 12))
# Out:
# ('michael schumacher', ('nelson piquet', ('emerson fittipaldi', ('alain prost', ('ayrton senna', ('max verstappen', ('charles leclerc', None)))))))
# ('rehcamuhcS leahciM', ('teuqiP nosleN', ('idlapittiF nosremE', ('tsorP nialA', ('anneS notryA', ('neppatsreV xaM', ('crelceL selrahC', None)))))))
# ('Nelson Piquet', ('Emerson Fittipaldi', ('Alain Prost', ('Max Verstappen', None))))
# ('Alain Prost', ('Ayrton Senna', None))
